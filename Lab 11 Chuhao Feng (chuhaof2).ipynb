# %% [markdown]
# # Lab 11: ODEs, Failure Rates, and Evolutionary Games

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
from scipy.integrate import odeint
print ('Modules Imported!')
# Out:
# Modules Imported!

# %% [markdown]
# In this lab we're to going analyze evolutionary games using drift analysis. In order to do this, we first need to determine how to integrate ordinary differential equations. So, we begin with a brief exposure of how to achieve this in Python. While we're at it, we'll do a short exercise about failure rate functions.  Then we examine some evolutionary games, using both a stochastic model and a deterministic model, which involves the differential equations.

# %% [markdown]
# ## Integration of ODEs

# %% [markdown]
# This section gives an introdution to integrating ordinary differential equations (odes), with an application to the calculation of a CDF from a failure rate function.  If you recall from your math classes we can describe an ODE as the following:
#
# $\dot{y}=f(y),$
#
# where both $y$ and the function $f$ are vector valued, and $\dot{y}$ is shorthand for $\frac{dy}{dt}.$   The variables being vector valued simply implies that we could have a system of dependent one dimensional (1D) ODEs as opposed to just a single one dimensional variable.  Let's look at the following system:
#
# \begin{eqnarray*}
# \binom{\dot{y_0}}{\dot{y_1}} = \binom{2y_1-0.1y_0}{-y_0}
# \end{eqnarray*}
# with the initial condition $y_{init}=\binom{y_0(0)}{y_1(0)}=\binom{1}{1}.$
#
# Our goal in using Python is not to find a closed form solution to the ODE as you would have probably done in your math class, but to numerically integrate it and produce a graphical solution. In order to do this we use the odeint method from scipy.integrate. It takes a function with an initial value and specified times at which the solution is to be output. Internally, the numerical method will often use a much finer grid of time points to solve the ode -- but that is none of your concern.   The times you put in are the times at with the method needs to provide the values of the solution. Look how it is used below:

# %%
# Simple example integrating a 2d ordinary differential equation (ode) dy/dt=f(y,t) 
# Note that the odeint package is imported in the code at the beginning of this file.

# Function to integrate over
def f(y,t):    
    return np.array([2.*y[1]-.1*y[0],-y[0] ])

time=np.linspace(0.0,20.0,10000)   # The times at which the solution is output.
yinit=np.array([1.0,1.0])   # The initial condition
y=odeint(f,yinit,time)      

plt.plot(y[:,0],y[:,1])
plt.title('trajectory of y up to time 20')
plt.ylabel('y_1')
plt.xlabel('y_0')
# Out:
# Text(0.5, 0, 'y_0')

# %% [markdown]
# Typically in a plot like this you would add an arrow to indicate the direction of time in the graph. However, we know the initial state is $y_{init}=\binom{1}{1}.$ So as time increases, the trajectory moves concentrically inwards in a clockwise fashion. Depending on how much of differential equations you remember, this solution should make sense. The equation happens to have a linear form and can be written as $\dot y = Ay$ where
# $
# A=\left( \begin{array}{cc}  -0.1  &  2  \\  -1  & 0 \end{array} \right).
# $
# The eigenvalues of $A$ are complex with negative real parts, so we would expect a decaying oscillatory behavior. (If you didn't follow that, don't worry about it.)
#
# As a simple application of integrating a 1D (one-dimensional) ode, the following code calculates a CDF $F$ from its failure rate function $h.$ But first, let's look at some theory to remember what a failure rate function is. If we let $T$ be a positive random variable with a pdf $f_T$ then
# the failure rate function is defined by the following:
#
# $$h(t)=\lim_{\epsilon \to 0} \frac{P(t<T \leq t+\epsilon | T>t)}{\epsilon}$$
#
# Equivalently, an object having failure rate function $h$ means that for any $t > 0,$ given
# that the object is still working at time $t$, the probability it will fail in the next
# $\epsilon$ time units is $h(t)\epsilon + o(\epsilon)$.  (As usual, $o(\epsilon)$ represents an error term such that $o(\epsilon)/\epsilon \to 0$ as $\epsilon\to 0.$)  With a little bit more derivation (shown in Section 3.9 of your ECE 313 text), we can see that:
#
# $$h(t) = \frac{f_T(t)}{1-F_T(t)}$$
#
# Of course, the pdf $f_T$ is the derivative of the CDF $F_T$. Here's where your 1D ODE comes into play. Given a failure rate function, we want to be able to calculate the CDF. We can easily turn this into an ODE.
#
# $f_T(t) = (1-F_T(t))h(t)$
#
# Let $F_T(t) = y$ and  $f_T(t) = \frac{dy}{dt} = \dot{y}$, then:
#
# $\dot{y} = (1-y)h(t)$
#
# Now we have our differential equation set up and we can solve it by the same method used in the previous example. For the code below, we define a particular bathtub shaped failure rate function to model the lifetime of a component such as a hard disk drive. There is a high, but decreasing initial rate of failure, followed be a period with a very low rate failure, followed by an increasing rate of failure. You should be able to think of reasons why an object might exhibit this type of failure rate function. Notice that the CDF behaves as we would expect: always between 0 and 1, and reactive to $h(t)$.
#
# If you examine the ECE 313 notes you'll see another way to determine $F_T,$  namely, using
# $F_T(t) = 1- \exp \left( \int_o^t -h(s) ds \right)$.  The point here, though, is to get some practice using
# odeint, instead of using this formula.

# %%
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)
    

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

plt.plot(time,list(map(h,time)))
plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
plt.text(4,0.5, r'$F(t)$',fontsize=24) 

plt.plot(time,F)
plt.title('failure rate function $h$ and associated CDF, $F$')
plt.axis(ymin=0,ymax=2.0)
plt.ylabel('$h(t), F(t)$',fontsize=20)
plt.xlabel('$t$',fontsize=20)
# Out:
# Text(0.5, 0, '$t$')

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 1:</SPAN>** Using the information on failure rate functions and the example above, do the following:
# <ol>
# <li> Write code that, given the failure rate function of a random variable $T$, computes the mean lifetime, $E[T].$  Use this code to determine the mean lifetime for the example given above.  (Hint: An easy way to do this problem is to use the area rule for expectations. Since $T$ is nonnegative, the area rule for expectations gives $E[T]=\int_0^\infty(1-F(t)) dt.$
# The integral $\int_0^\infty (1-F(t)) dt$ is approximately equal to
# $\int_0^{t_{max}} (1-F(t)) dt,$  which, by the definition of Riemann integration, is approximately equal to
# $h \sum_{i=1}^{1000} (1-F(h_i)) $ where $h=t_{max}/1000.$  Basically the code above returns the samples $F(h_i)$ so all you need to do is subtract these values from 1, sum them up and multiply by $h$.)
# <li> What happens to $E[T]$ if the failure rate function is doubled for all time? Print out the new value of $E[T]$.
# </ol>

# %%
# Your code here

# part 1
delta_h = t_max/1000
E_T = (1-F).sum() * delta_h

print('Part 1')
print('The mean lifetime:', E_T)

# part 2
def h_2(t):   # doubled h for all time
    if t<1:
        return 2*(1-t)
    elif t<3:
        return 2*0.0
    else:
        return 2*(np.sqrt(t-3))
    

def Fdot_2(y,t):    
    return (1-y)*h_2(t)

Finit=0.0
F_2=odeint(Fdot_2,Finit,time)

E_T_2 = (1-F_2).sum() * delta_h

print('\nPart 2')
print('The mean lifetime:', E_T_2)
# Out:
# Part 1
# The mean lifetime: 2.656524220052057
#
# Part 2
# The mean lifetime: 1.550444859245456

# %% [markdown]
# __Answer:__ $E[T]$ will decrease if the failure rate function is doubled for all time. The result is expected, because the mean lifetime should decrease given a doubled failure rate.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 1</SPAN>**

# %% [markdown]
# ## Evolutionary games (replicator dynamics):

# %% [markdown]
# Consider a population of individuals, where each individual is of some type.  Suppose individuals have occasional pairwise encounters.  During an encounter the two individuals involved play a two player symmetric game in which the strategies are the types of the individuals.   As a result of the encounter, each of the two individuals produces a number of offspring of its same type, with the number being determined by a fitess table or, equivalently, a fitness matrix.   For example, consider a population of crickets such that each cricket is either small or large.   If two small crickets meet each other then they each spawn five more small crickets.  If a small cricket encounters a large cricket then the small cricket spawns one more small cricket and the large cricket spawns eight new large crickets.   If two large crickets meet then each of them spawns three new large crickets.  We can summarize these outcomes using the following table:
# $$\begin{array}{c|cc}  & small & large  \\ \hline
#     small & 5 & 1  \\
#     large & 8 & 3
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  5 & 1 \\ 8 & 3  \end{array}\right).$$
# Associating 0 with "small" and 1 with "large,"  we see that if a type i individual encounters a type j individual, then the type i individual spawns F[i,j] new individuals of type i, and the type j individual spawns F[j,i] new individuals of type j. Below is a stochastic simulation for this game where we start with a population of four small crickets and four large crickets. It may be a useful exercise for you to think of how the values for $a$ and $b$ were created.

# %%
# Stochastic simulation of replicator dynamics for cricket game

F=np.array([[5,1],[8,3]])  # fitness matrix

n=np.array([4,4])  #[number of small crickets, number of large crickets], initialized
print ("                                   State      Fractions of each type")
print ("Initially                        ", n, "      ", n/1./np.sum(n))

T = 1000 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print ("Round",k+1,"two small crickets meet ", n, n/1./np.sum(n))
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print ("Round",k+1,"a small meets a large   ", n, n/1./np.sum(n))
    else:
        n+=[0,2*F[1,1]]
        print ("Round",k+1,"two large crickets meet ", n, n/1./np.sum(n))
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [0.5 0.5]
# Round 1 a small meets a large    [ 5 12] [0.29411765 0.70588235]
# Round 2 a small meets a large    [ 6 20] [0.23076923 0.76923077]
# Round 3 two large crickets meet  [ 6 26] [0.1875 0.8125]
# Round 4 two large crickets meet  [ 6 32] [0.15789474 0.84210526]
# Round 5 two large crickets meet  [ 6 38] [0.13636364 0.86363636]
# Round 6 two large crickets meet  [ 6 44] [0.12 0.88]
# Round 7 two large crickets meet  [ 6 50] [0.10714286 0.89285714]
# Round 8 two large crickets meet  [ 6 56] [0.09677419 0.90322581]
# Round 9 two large crickets meet  [ 6 62] [0.08823529 0.91176471]
# Round 10 two small crickets meet  [16 62] [0.20512821 0.79487179]
# Round 11 a small meets a large    [17 70] [0.1954023 0.8045977]
# Round 12 a small meets a large    [18 78] [0.1875 0.8125]
# Round 13 two large crickets meet  [18 84] [0.17647059 0.82352941]
# Round 14 two large crickets meet  [18 90] [0.16666667 0.83333333]
# Round 15 a small meets a large    [19 98] [0.16239316 0.83760684]
# Round 16 two large crickets meet  [ 19 104] [0.15447154 0.84552846]
# Round 17 two large crickets meet  [ 19 110] [0.14728682 0.85271318]
# Round 18 two large crickets meet  [ 19 116] [0.14074074 0.85925926]
# Round 19 a small meets a large    [ 20 124] [0.13888889 0.86111111]
# Round 20 two large crickets meet  [ 20 130] [0.13333333 0.86666667]
# Round 21 two large crickets meet  [ 20 136] [0.12820513 0.87179487]
# Round 22 two large crickets meet  [ 20 142] [0.12345679 0.87654321]
# Round 23 two large crickets meet  [ 20 148] [0.11904762 0.88095238]
# Round 24 two large crickets meet  [ 20 154] [0.11494253 0.88505747]
# Round 25 two large crickets meet  [ 20 160] [0.11111111 0.88888889]
# Round 26 two large crickets meet  [ 20 166] [0.10752688 0.89247312]
# Round 27 two large crickets meet  [ 20 172] [0.10416667 0.89583333]
# Round 28 a small meets a large    [ 21 180] [0.10447761 0.89552239]
# Round 29 two large crickets meet  [ 21 186] [0.10144928 0.89855072]
# Round 30 two large crickets meet  [ 21 192] [0.09859155 0.90140845]
# Round 31 two large crickets meet  [ 21 198] [0.09589041 0.90410959]
# Round 32 two large crickets meet  [ 21 204] [0.09333333 0.90666667]
# Round 33 two large crickets meet  [ 21 210] [0.09090909 0.90909091]
# Round 34 two large crickets meet  [ 21 216] [0.08860759 0.91139241]
# Round 35 two large crickets meet  [ 21 222] [0.08641975 0.91358025]
# Round 36 two large crickets meet  [ 21 228] [0.08433735 0.91566265]
# Round 37 two large crickets meet  [ 21 234] [0.08235294 0.91764706]
# Round 38 two large crickets meet  [ 21 240] [0.08045977 0.91954023]
# Round 39 two large crickets meet  [ 21 246] [0.07865169 0.92134831]
# Round 40 two large crickets meet  [ 21 252] [0.07692308 0.92307692]
# Round 41 two large crickets meet  [ 21 258] [0.07526882 0.92473118]
# Round 42 two large crickets meet  [ 21 264] [0.07368421 0.92631579]
# Round 43 two large crickets meet  [ 21 270] [0.07216495 0.92783505]
# Round 44 two large crickets meet  [ 21 276] [0.07070707 0.92929293]
# Round 45 two large crickets meet  [ 21 282] [0.06930693 0.93069307]
# Round 46 two large crickets meet  [ 21 288] [0.06796117 0.93203883]
# Round 47 two large crickets meet  [ 21 294] [0.06666667 0.93333333]
# Round 48 two large crickets meet  [ 21 300] [0.06542056 0.93457944]
# Round 49 a small meets a large    [ 22 308] [0.06666667 0.93333333]
# Round 50 two large crickets meet  [ 22 314] [0.06547619 0.93452381]
# Round 51 two large crickets meet  [ 22 320] [0.06432749 0.93567251]
# Round 52 two large crickets meet  [ 22 326] [0.06321839 0.93678161]
# Round 53 two large crickets meet  [ 22 332] [0.06214689 0.93785311]
# Round 54 two large crickets meet  [ 22 338] [0.06111111 0.93888889]
# Round 55 two large crickets meet  [ 22 344] [0.06010929 0.93989071]
# Round 56 two large crickets meet  [ 22 350] [0.05913978 0.94086022]
# Round 57 two large crickets meet  [ 22 356] [0.05820106 0.94179894]
# Round 58 two large crickets meet  [ 22 362] [0.05729167 0.94270833]
# Round 59 two large crickets meet  [ 22 368] [0.05641026 0.94358974]
# Round 60 two large crickets meet  [ 22 374] [0.05555556 0.94444444]
# Round 61 two large crickets meet  [ 22 380] [0.05472637 0.94527363]
# Round 62 two large crickets meet  [ 22 386] [0.05392157 0.94607843]
# Round 63 two large crickets meet  [ 22 392] [0.0531401 0.9468599]
# Round 64 two large crickets meet  [ 22 398] [0.05238095 0.94761905]
# Round 65 two large crickets meet  [ 22 404] [0.05164319 0.94835681]
# Round 66 two large crickets meet  [ 22 410] [0.05092593 0.94907407]
# Round 67 two large crickets meet  [ 22 416] [0.05022831 0.94977169]
# Round 68 two large crickets meet  [ 22 422] [0.04954955 0.95045045]
# Round 69 two large crickets meet  [ 22 428] [0.04888889 0.95111111]
# Round 70 two large crickets meet  [ 22 434] [0.04824561 0.95175439]
# Round 71 two large crickets meet  [ 22 440] [0.04761905 0.95238095]
# Round 72 two large crickets meet  [ 22 446] [0.04700855 0.95299145]
# Round 73 two large crickets meet  [ 22 452] [0.0464135 0.9535865]
# Round 74 two large crickets meet  [ 22 458] [0.04583333 0.95416667]
# Round 75 two large crickets meet  [ 22 464] [0.04526749 0.95473251]
# Round 76 two large crickets meet  [ 22 470] [0.04471545 0.95528455]
# Round 77 two large crickets meet  [ 22 476] [0.04417671 0.95582329]
# Round 78 two large crickets meet  [ 22 482] [0.04365079 0.95634921]
# Round 79 two large crickets meet  [ 22 488] [0.04313725 0.95686275]
# Round 80 two large crickets meet  [ 22 494] [0.04263566 0.95736434]
# Round 81 a small meets a large    [ 23 502] [0.04380952 0.95619048]
# Round 82 two large crickets meet  [ 23 508] [0.0433145 0.9566855]
# Round 83 two large crickets meet  [ 23 514] [0.04283054 0.95716946]
# Round 84 two large crickets meet  [ 23 520] [0.04235727 0.95764273]
# Round 85 a small meets a large    [ 24 528] [0.04347826 0.95652174]
# Round 86 two large crickets meet  [ 24 534] [0.04301075 0.95698925]
# Round 87 two large crickets meet  [ 24 540] [0.04255319 0.95744681]
# Round 88 two large crickets meet  [ 24 546] [0.04210526 0.95789474]
# Round 89 two large crickets meet  [ 24 552] [0.04166667 0.95833333]
# Round 90 two large crickets meet  [ 24 558] [0.04123711 0.95876289]
# Round 91 two large crickets meet  [ 24 564] [0.04081633 0.95918367]
# Round 92 two large crickets meet  [ 24 570] [0.04040404 0.95959596]
# Round 93 a small meets a large    [ 25 578] [0.04145937 0.95854063]
# Round 94 two large crickets meet  [ 25 584] [0.0410509 0.9589491]
# Round 95 two large crickets meet  [ 25 590] [0.04065041 0.95934959]
# Round 96 two large crickets meet  [ 25 596] [0.04025765 0.95974235]
# Round 97 two large crickets meet  [ 25 602] [0.03987241 0.96012759]
# Round 98 two large crickets meet  [ 25 608] [0.03949447 0.96050553]
# Round 99 two large crickets meet  [ 25 614] [0.03912363 0.96087637]
# Round 100 two large crickets meet  [ 25 620] [0.03875969 0.96124031]
# Round 101 two large crickets meet  [ 25 626] [0.03840246 0.96159754]
# Round 102 two large crickets meet  [ 25 632] [0.03805175 0.96194825]
# Round 103 two large crickets meet  [ 25 638] [0.03770739 0.96229261]
# Round 104 two large crickets meet  [ 25 644] [0.03736921 0.96263079]
# Round 105 two large crickets meet  [ 25 650] [0.03703704 0.96296296]
# Round 106 two large crickets meet  [ 25 656] [0.03671072 0.96328928]
# Round 107 two large crickets meet  [ 25 662] [0.0363901 0.9636099]
# Round 108 two large crickets meet  [ 25 668] [0.03607504 0.96392496]
# Round 109 two large crickets meet  [ 25 674] [0.03576538 0.96423462]
# Round 110 two large crickets meet  [ 25 680] [0.03546099 0.96453901]
# Round 111 two large crickets meet  [ 25 686] [0.03516174 0.96483826]
# Round 112 two large crickets meet  [ 25 692] [0.0348675 0.9651325]
# Round 113 two large crickets meet  [ 25 698] [0.03457815 0.96542185]
# Round 114 two large crickets meet  [ 25 704] [0.03429355 0.96570645]
# Round 115 two large crickets meet  [ 25 710] [0.03401361 0.96598639]
# Round 116 two large crickets meet  [ 25 716] [0.03373819 0.96626181]
# Round 117 two large crickets meet  [ 25 722] [0.0334672 0.9665328]
# Round 118 two large crickets meet  [ 25 728] [0.03320053 0.96679947]
# Round 119 two large crickets meet  [ 25 734] [0.03293808 0.96706192]
# Round 120 two large crickets meet  [ 25 740] [0.03267974 0.96732026]
# Round 121 two large crickets meet  [ 25 746] [0.03242542 0.96757458]
# Round 122 two large crickets meet  [ 25 752] [0.03217503 0.96782497]
# Round 123 two large crickets meet  [ 25 758] [0.03192848 0.96807152]
# Round 124 two large crickets meet  [ 25 764] [0.03168568 0.96831432]
# Round 125 two large crickets meet  [ 25 770] [0.03144654 0.96855346]
# Round 126 two large crickets meet  [ 25 776] [0.03121099 0.96878901]
# Round 127 two large crickets meet  [ 25 782] [0.03097893 0.96902107]
# Round 128 two large crickets meet  [ 25 788] [0.03075031 0.96924969]
# Round 129 two large crickets meet  [ 25 794] [0.03052503 0.96947497]
# Round 130 two large crickets meet  [ 25 800] [0.03030303 0.96969697]
# Round 131 two large crickets meet  [ 25 806] [0.03008424 0.96991576]
# Round 132 two large crickets meet  [ 25 812] [0.02986858 0.97013142]
# Round 133 two large crickets meet  [ 25 818] [0.02965599 0.97034401]
# Round 134 two large crickets meet  [ 25 824] [0.02944641 0.97055359]
# Round 135 two large crickets meet  [ 25 830] [0.02923977 0.97076023]
# Round 136 two large crickets meet  [ 25 836] [0.029036 0.970964]
# Round 137 two large crickets meet  [ 25 842] [0.02883506 0.97116494]
# Round 138 two large crickets meet  [ 25 848] [0.02863688 0.97136312]
# Round 139 two large crickets meet  [ 25 854] [0.02844141 0.97155859]
# Round 140 two large crickets meet  [ 25 860] [0.02824859 0.97175141]
# Round 141 two large crickets meet  [ 25 866] [0.02805836 0.97194164]
# Round 142 two large crickets meet  [ 25 872] [0.02787068 0.97212932]
# Round 143 two large crickets meet  [ 25 878] [0.02768549 0.97231451]
# Round 144 two large crickets meet  [ 25 884] [0.02750275 0.97249725]
# Round 145 a small meets a large    [ 26 892] [0.02832244 0.97167756]
# Round 146 two large crickets meet  [ 26 898] [0.02813853 0.97186147]
# Round 147 two large crickets meet  [ 26 904] [0.02795699 0.97204301]
# Round 148 two large crickets meet  [ 26 910] [0.02777778 0.97222222]
# Round 149 two large crickets meet  [ 26 916] [0.02760085 0.97239915]
# Round 150 two large crickets meet  [ 26 922] [0.02742616 0.97257384]
# Round 151 two large crickets meet  [ 26 928] [0.02725367 0.97274633]
# Round 152 a small meets a large    [ 27 936] [0.02803738 0.97196262]
# Round 153 two large crickets meet  [ 27 942] [0.02786378 0.97213622]
# Round 154 two large crickets meet  [ 27 948] [0.02769231 0.97230769]
# Round 155 two large crickets meet  [ 27 954] [0.02752294 0.97247706]
# Round 156 two large crickets meet  [ 27 960] [0.02735562 0.97264438]
# Round 157 two large crickets meet  [ 27 966] [0.02719033 0.97280967]
# Round 158 two large crickets meet  [ 27 972] [0.02702703 0.97297297]
# Round 159 two large crickets meet  [ 27 978] [0.02686567 0.97313433]
# Round 160 two large crickets meet  [ 27 984] [0.02670623 0.97329377]
# Round 161 two large crickets meet  [ 27 990] [0.02654867 0.97345133]
# Round 162 two large crickets meet  [ 27 996] [0.02639296 0.97360704]
# Round 163 two large crickets meet  [  27 1002] [0.02623907 0.97376093]
# Round 164 two large crickets meet  [  27 1008] [0.02608696 0.97391304]
# Round 165 two large crickets meet  [  27 1014] [0.0259366 0.9740634]
# Round 166 two large crickets meet  [  27 1020] [0.02578797 0.97421203]
# Round 167 two large crickets meet  [  27 1026] [0.02564103 0.97435897]
# Round 168 two large crickets meet  [  27 1032] [0.02549575 0.97450425]
# Round 169 two large crickets meet  [  27 1038] [0.02535211 0.97464789]
# Round 170 two large crickets meet  [  27 1044] [0.02521008 0.97478992]
# Round 171 two large crickets meet  [  27 1050] [0.02506964 0.97493036]
# Round 172 two large crickets meet  [  27 1056] [0.02493075 0.97506925]
# Round 173 two large crickets meet  [  27 1062] [0.02479339 0.97520661]
# Round 174 two large crickets meet  [  27 1068] [0.02465753 0.97534247]
# Round 175 two large crickets meet  [  27 1074] [0.02452316 0.97547684]
# Round 176 two large crickets meet  [  27 1080] [0.02439024 0.97560976]
# Round 177 two large crickets meet  [  27 1086] [0.02425876 0.97574124]
# Round 178 two large crickets meet  [  27 1092] [0.02412869 0.97587131]
# Round 179 two large crickets meet  [  27 1098] [0.024 0.976]
# Round 180 two large crickets meet  [  27 1104] [0.02387268 0.97612732]
# Round 181 a small meets a large    [  28 1112] [0.0245614 0.9754386]
# Round 182 two large crickets meet  [  28 1118] [0.02443281 0.97556719]
# Round 183 two large crickets meet  [  28 1124] [0.02430556 0.97569444]
# Round 184 two large crickets meet  [  28 1130] [0.02417962 0.97582038]
# Round 185 two large crickets meet  [  28 1136] [0.02405498 0.97594502]
# Round 186 two large crickets meet  [  28 1142] [0.02393162 0.97606838]
# Round 187 two large crickets meet  [  28 1148] [0.02380952 0.97619048]
# Round 188 two large crickets meet  [  28 1154] [0.02368866 0.97631134]
# Round 189 two large crickets meet  [  28 1160] [0.02356902 0.97643098]
# Round 190 two large crickets meet  [  28 1166] [0.02345059 0.97654941]
# Round 191 two large crickets meet  [  28 1172] [0.02333333 0.97666667]
# Round 192 two large crickets meet  [  28 1178] [0.02321725 0.97678275]
# Round 193 two large crickets meet  [  28 1184] [0.02310231 0.97689769]
# Round 194 two large crickets meet  [  28 1190] [0.02298851 0.97701149]
# Round 195 two large crickets meet  [  28 1196] [0.02287582 0.97712418]
# Round 196 two large crickets meet  [  28 1202] [0.02276423 0.97723577]
# Round 197 two large crickets meet  [  28 1208] [0.02265372 0.97734628]
# Round 198 two large crickets meet  [  28 1214] [0.02254428 0.97745572]
# Round 199 two large crickets meet  [  28 1220] [0.0224359 0.9775641]
# Round 200 two large crickets meet  [  28 1226] [0.02232855 0.97767145]
# Round 201 two large crickets meet  [  28 1232] [0.02222222 0.97777778]
# Round 202 two large crickets meet  [  28 1238] [0.0221169 0.9778831]
# Round 203 two large crickets meet  [  28 1244] [0.02201258 0.97798742]
# Round 204 two large crickets meet  [  28 1250] [0.02190923 0.97809077]
# Round 205 two large crickets meet  [  28 1256] [0.02180685 0.97819315]
# Round 206 two large crickets meet  [  28 1262] [0.02170543 0.97829457]
# Round 207 two large crickets meet  [  28 1268] [0.02160494 0.97839506]
# Round 208 two large crickets meet  [  28 1274] [0.02150538 0.97849462]
# Round 209 a small meets a large    [  29 1282] [0.02212052 0.97787948]
# Round 210 two large crickets meet  [  29 1288] [0.02201974 0.97798026]
# Round 211 two large crickets meet  [  29 1294] [0.02191988 0.97808012]
# Round 212 two large crickets meet  [  29 1300] [0.02182092 0.97817908]
# Round 213 two large crickets meet  [  29 1306] [0.02172285 0.97827715]
# Round 214 two large crickets meet  [  29 1312] [0.02162565 0.97837435]
# Round 215 two large crickets meet  [  29 1318] [0.02152932 0.97847068]
# Round 216 two large crickets meet  [  29 1324] [0.02143385 0.97856615]
# Round 217 two large crickets meet  [  29 1330] [0.02133922 0.97866078]
# Round 218 two large crickets meet  [  29 1336] [0.02124542 0.97875458]
# Round 219 two large crickets meet  [  29 1342] [0.02115244 0.97884756]
# Round 220 two large crickets meet  [  29 1348] [0.02106028 0.97893972]
# Round 221 two large crickets meet  [  29 1354] [0.02096891 0.97903109]
# Round 222 two large crickets meet  [  29 1360] [0.02087833 0.97912167]
# Round 223 two large crickets meet  [  29 1366] [0.02078853 0.97921147]
# Round 224 two large crickets meet  [  29 1372] [0.0206995 0.9793005]
# Round 225 two large crickets meet  [  29 1378] [0.02061123 0.97938877]
# Round 226 two large crickets meet  [  29 1384] [0.02052371 0.97947629]
# Round 227 two large crickets meet  [  29 1390] [0.02043693 0.97956307]
# Round 228 two small crickets meet  [  39 1390] [0.02729181 0.97270819]
# Round 229 two large crickets meet  [  39 1396] [0.0271777 0.9728223]
# Round 230 two large crickets meet  [  39 1402] [0.02706454 0.97293546]
# Round 231 two large crickets meet  [  39 1408] [0.02695232 0.97304768]
# Round 232 two large crickets meet  [  39 1414] [0.02684102 0.97315898]
# Round 233 two large crickets meet  [  39 1420] [0.02673064 0.97326936]
# Round 234 two large crickets meet  [  39 1426] [0.02662116 0.97337884]
# Round 235 two large crickets meet  [  39 1432] [0.02651258 0.97348742]
# Round 236 two large crickets meet  [  39 1438] [0.02640487 0.97359513]
# Round 237 two large crickets meet  [  39 1444] [0.02629804 0.97370196]
# Round 238 two large crickets meet  [  39 1450] [0.02619208 0.97380792]
# Round 239 two large crickets meet  [  39 1456] [0.02608696 0.97391304]
# Round 240 two large crickets meet  [  39 1462] [0.02598268 0.97401732]
# Round 241 a small meets a large    [  40 1470] [0.02649007 0.97350993]
# Round 242 two large crickets meet  [  40 1476] [0.02638522 0.97361478]
# Round 243 two large crickets meet  [  40 1482] [0.02628121 0.97371879]
# Round 244 two large crickets meet  [  40 1488] [0.02617801 0.97382199]
# Round 245 two large crickets meet  [  40 1494] [0.02607562 0.97392438]
# Round 246 two large crickets meet  [  40 1500] [0.02597403 0.97402597]
# Round 247 two large crickets meet  [  40 1506] [0.02587322 0.97412678]
# Round 248 two large crickets meet  [  40 1512] [0.0257732 0.9742268]
# Round 249 two large crickets meet  [  40 1518] [0.02567394 0.97432606]
# Round 250 two large crickets meet  [  40 1524] [0.02557545 0.97442455]
# Round 251 two large crickets meet  [  40 1530] [0.02547771 0.97452229]
# Round 252 two large crickets meet  [  40 1536] [0.02538071 0.97461929]
# Round 253 two large crickets meet  [  40 1542] [0.02528445 0.97471555]
# Round 254 two large crickets meet  [  40 1548] [0.02518892 0.97481108]
# Round 255 two large crickets meet  [  40 1554] [0.0250941 0.9749059]
# Round 256 two large crickets meet  [  40 1560] [0.025 0.975]
# Round 257 two large crickets meet  [  40 1566] [0.0249066 0.9750934]
# Round 258 two large crickets meet  [  40 1572] [0.0248139 0.9751861]
# Round 259 two large crickets meet  [  40 1578] [0.02472188 0.97527812]
# Round 260 two large crickets meet  [  40 1584] [0.02463054 0.97536946]
# Round 261 two large crickets meet  [  40 1590] [0.02453988 0.97546012]
# Round 262 two large crickets meet  [  40 1596] [0.02444988 0.97555012]
# Round 263 two large crickets meet  [  40 1602] [0.02436054 0.97563946]
# Round 264 two large crickets meet  [  40 1608] [0.02427184 0.97572816]
# Round 265 two large crickets meet  [  40 1614] [0.0241838 0.9758162]
# Round 266 two large crickets meet  [  40 1620] [0.02409639 0.97590361]
# Round 267 two large crickets meet  [  40 1626] [0.0240096 0.9759904]
# Round 268 a small meets a large    [  41 1634] [0.02447761 0.97552239]
# Round 269 two large crickets meet  [  41 1640] [0.02439024 0.97560976]
# Round 270 two large crickets meet  [  41 1646] [0.0243035 0.9756965]
# Round 271 two large crickets meet  [  41 1652] [0.02421737 0.97578263]
# Round 272 two large crickets meet  [  41 1658] [0.02413184 0.97586816]
# Round 273 two large crickets meet  [  41 1664] [0.02404692 0.97595308]
# Round 274 two large crickets meet  [  41 1670] [0.02396259 0.97603741]
# Round 275 a small meets a large    [  42 1678] [0.0244186 0.9755814]
# Round 276 two large crickets meet  [  42 1684] [0.02433372 0.97566628]
# Round 277 two large crickets meet  [  42 1690] [0.02424942 0.97575058]
# Round 278 two large crickets meet  [  42 1696] [0.02416571 0.97583429]
# Round 279 two large crickets meet  [  42 1702] [0.02408257 0.97591743]
# Round 280 two large crickets meet  [  42 1708] [0.024 0.976]
# Round 281 two large crickets meet  [  42 1714] [0.023918 0.976082]
# Round 282 two large crickets meet  [  42 1720] [0.02383655 0.97616345]
# Round 283 two large crickets meet  [  42 1726] [0.02375566 0.97624434]
# Round 284 two large crickets meet  [  42 1732] [0.02367531 0.97632469]
# Round 285 two large crickets meet  [  42 1738] [0.02359551 0.97640449]
# Round 286 two large crickets meet  [  42 1744] [0.02351624 0.97648376]
# Round 287 two large crickets meet  [  42 1750] [0.0234375 0.9765625]
# Round 288 two large crickets meet  [  42 1756] [0.02335929 0.97664071]
# Round 289 two large crickets meet  [  42 1762] [0.0232816 0.9767184]
# Round 290 two large crickets meet  [  42 1768] [0.02320442 0.97679558]
# Round 291 two large crickets meet  [  42 1774] [0.02312775 0.97687225]
# Round 292 two large crickets meet  [  42 1780] [0.02305159 0.97694841]
# Round 293 two large crickets meet  [  42 1786] [0.02297593 0.97702407]
# Round 294 two large crickets meet  [  42 1792] [0.02290076 0.97709924]
# Round 295 two large crickets meet  [  42 1798] [0.02282609 0.97717391]
# Round 296 two large crickets meet  [  42 1804] [0.0227519 0.9772481]
# Round 297 two large crickets meet  [  42 1810] [0.02267819 0.97732181]
# Round 298 two large crickets meet  [  42 1816] [0.02260495 0.97739505]
# Round 299 two large crickets meet  [  42 1822] [0.02253219 0.97746781]
# Round 300 two large crickets meet  [  42 1828] [0.02245989 0.97754011]
# Round 301 two large crickets meet  [  42 1834] [0.02238806 0.97761194]
# Round 302 two large crickets meet  [  42 1840] [0.02231668 0.97768332]
# Round 303 two large crickets meet  [  42 1846] [0.02224576 0.97775424]
# Round 304 a small meets a large    [  43 1854] [0.02266737 0.97733263]
# Round 305 two large crickets meet  [  43 1860] [0.0225959 0.9774041]
# Round 306 two large crickets meet  [  43 1866] [0.02252488 0.97747512]
# Round 307 two large crickets meet  [  43 1872] [0.02245431 0.97754569]
# Round 308 two large crickets meet  [  43 1878] [0.02238417 0.97761583]
# Round 309 two large crickets meet  [  43 1884] [0.02231448 0.97768552]
# Round 310 two large crickets meet  [  43 1890] [0.02224521 0.97775479]
# Round 311 two large crickets meet  [  43 1896] [0.02217638 0.97782362]
# Round 312 two large crickets meet  [  43 1902] [0.02210797 0.97789203]
# Round 313 two large crickets meet  [  43 1908] [0.02203998 0.97796002]
# Round 314 two large crickets meet  [  43 1914] [0.02197241 0.97802759]
# Round 315 a small meets a large    [  44 1922] [0.02238047 0.97761953]
# Round 316 two large crickets meet  [  44 1928] [0.02231237 0.97768763]
# Round 317 two large crickets meet  [  44 1934] [0.02224469 0.97775531]
# Round 318 two large crickets meet  [  44 1940] [0.02217742 0.97782258]
# Round 319 two large crickets meet  [  44 1946] [0.02211055 0.97788945]
# Round 320 two large crickets meet  [  44 1952] [0.02204409 0.97795591]
# Round 321 two large crickets meet  [  44 1958] [0.02197802 0.97802198]
# Round 322 two large crickets meet  [  44 1964] [0.02191235 0.97808765]
# Round 323 two large crickets meet  [  44 1970] [0.02184707 0.97815293]
# Round 324 a small meets a large    [  45 1978] [0.02224419 0.97775581]
# Round 325 two large crickets meet  [  45 1984] [0.02217841 0.97782159]
# Round 326 two large crickets meet  [  45 1990] [0.02211302 0.97788698]
# Round 327 two large crickets meet  [  45 1996] [0.02204802 0.97795198]
# Round 328 a small meets a large    [  46 2004] [0.02243902 0.97756098]
# Round 329 two large crickets meet  [  46 2010] [0.02237354 0.97762646]
# Round 330 two large crickets meet  [  46 2016] [0.02230844 0.97769156]
# Round 331 two large crickets meet  [  46 2022] [0.02224371 0.97775629]
# Round 332 a small meets a large    [  47 2030] [0.02262879 0.97737121]
# Round 333 two large crickets meet  [  47 2036] [0.02256361 0.97743639]
# Round 334 two large crickets meet  [  47 2042] [0.0224988 0.9775012]
# Round 335 two large crickets meet  [  47 2048] [0.02243437 0.97756563]
# Round 336 two large crickets meet  [  47 2054] [0.0223703 0.9776297]
# Round 337 two large crickets meet  [  47 2060] [0.0223066 0.9776934]
# Round 338 two large crickets meet  [  47 2066] [0.02224326 0.97775674]
# Round 339 two large crickets meet  [  47 2072] [0.02218027 0.97781973]
# Round 340 two large crickets meet  [  47 2078] [0.02211765 0.97788235]
# Round 341 two large crickets meet  [  47 2084] [0.02205537 0.97794463]
# Round 342 two large crickets meet  [  47 2090] [0.02199345 0.97800655]
# Round 343 two large crickets meet  [  47 2096] [0.02193187 0.97806813]
# Round 344 two large crickets meet  [  47 2102] [0.02187064 0.97812936]
# Round 345 two large crickets meet  [  47 2108] [0.02180974 0.97819026]
# Round 346 two large crickets meet  [  47 2114] [0.02174919 0.97825081]
# Round 347 two large crickets meet  [  47 2120] [0.02168897 0.97831103]
# Round 348 two large crickets meet  [  47 2126] [0.02162908 0.97837092]
# Round 349 two large crickets meet  [  47 2132] [0.02156953 0.97843047]
# Round 350 two large crickets meet  [  47 2138] [0.0215103 0.9784897]
# Round 351 two large crickets meet  [  47 2144] [0.02145139 0.97854861]
# Round 352 two large crickets meet  [  47 2150] [0.02139281 0.97860719]
# Round 353 two large crickets meet  [  47 2156] [0.02133454 0.97866546]
# Round 354 two large crickets meet  [  47 2162] [0.0212766 0.9787234]
# Round 355 two large crickets meet  [  47 2168] [0.02121896 0.97878104]
# Round 356 two large crickets meet  [  47 2174] [0.02116164 0.97883836]
# Round 357 two large crickets meet  [  47 2180] [0.02110463 0.97889537]
# Round 358 two large crickets meet  [  47 2186] [0.02104792 0.97895208]
# Round 359 a small meets a large    [  48 2194] [0.02140946 0.97859054]
# Round 360 two large crickets meet  [  48 2200] [0.02135231 0.97864769]
# Round 361 a small meets a large    [  49 2208] [0.02171023 0.97828977]
# Round 362 two large crickets meet  [  49 2214] [0.02165267 0.97834733]
# Round 363 two large crickets meet  [  49 2220] [0.02159542 0.97840458]
# Round 364 two large crickets meet  [  49 2226] [0.02153846 0.97846154]
# Round 365 two large crickets meet  [  49 2232] [0.02148181 0.97851819]
# Round 366 two large crickets meet  [  49 2238] [0.02142545 0.97857455]
# Round 367 two large crickets meet  [  49 2244] [0.02136939 0.97863061]
# Round 368 two large crickets meet  [  49 2250] [0.02131361 0.97868639]
# Round 369 two large crickets meet  [  49 2256] [0.02125813 0.97874187]
# Round 370 two large crickets meet  [  49 2262] [0.02120294 0.97879706]
# Round 371 two large crickets meet  [  49 2268] [0.02114804 0.97885196]
# Round 372 two large crickets meet  [  49 2274] [0.02109341 0.97890659]
# Round 373 two large crickets meet  [  49 2280] [0.02103907 0.97896093]
# Round 374 two large crickets meet  [  49 2286] [0.02098501 0.97901499]
# Round 375 two large crickets meet  [  49 2292] [0.02093123 0.97906877]
# Round 376 two large crickets meet  [  49 2298] [0.02087772 0.97912228]
# Round 377 two large crickets meet  [  49 2304] [0.02082448 0.97917552]
# Round 378 two large crickets meet  [  49 2310] [0.02077151 0.97922849]
# Round 379 two large crickets meet  [  49 2316] [0.02071882 0.97928118]
# Round 380 two large crickets meet  [  49 2322] [0.02066639 0.97933361]
# Round 381 two large crickets meet  [  49 2328] [0.02061422 0.97938578]
# Round 382 two large crickets meet  [  49 2334] [0.02056232 0.97943768]
# Round 383 two large crickets meet  [  49 2340] [0.02051067 0.97948933]
# Round 384 two large crickets meet  [  49 2346] [0.02045929 0.97954071]
# Round 385 two large crickets meet  [  49 2352] [0.02040816 0.97959184]
# Round 386 two large crickets meet  [  49 2358] [0.02035729 0.97964271]
# Round 387 two large crickets meet  [  49 2364] [0.02030667 0.97969333]
# Round 388 two large crickets meet  [  49 2370] [0.0202563 0.9797437]
# Round 389 two large crickets meet  [  49 2376] [0.02020619 0.97979381]
# Round 390 two large crickets meet  [  49 2382] [0.02015631 0.97984369]
# Round 391 two large crickets meet  [  49 2388] [0.02010669 0.97989331]
# Round 392 two large crickets meet  [  49 2394] [0.02005731 0.97994269]
# Round 393 two large crickets meet  [  49 2400] [0.02000817 0.97999183]
# Round 394 two large crickets meet  [  49 2406] [0.01995927 0.98004073]
# Round 395 two large crickets meet  [  49 2412] [0.01991061 0.98008939]
# Round 396 two large crickets meet  [  49 2418] [0.01986218 0.98013782]
# Round 397 two large crickets meet  [  49 2424] [0.01981399 0.98018601]
# Round 398 two large crickets meet  [  49 2430] [0.01976603 0.98023397]
# Round 399 two large crickets meet  [  49 2436] [0.01971831 0.98028169]
# Round 400 two large crickets meet  [  49 2442] [0.01967081 0.98032919]
# Round 401 two large crickets meet  [  49 2448] [0.01962355 0.98037645]
# Round 402 two large crickets meet  [  49 2454] [0.01957651 0.98042349]
# Round 403 two large crickets meet  [  49 2460] [0.01952969 0.98047031]
# Round 404 two large crickets meet  [  49 2466] [0.0194831 0.9805169]
# Round 405 two large crickets meet  [  49 2472] [0.01943673 0.98056327]
# Round 406 two large crickets meet  [  49 2478] [0.01939058 0.98060942]
# Round 407 two large crickets meet  [  49 2484] [0.01934465 0.98065535]
# Round 408 a small meets a large    [  50 2492] [0.01966955 0.98033045]
# Round 409 two large crickets meet  [  50 2498] [0.01962323 0.98037677]
# Round 410 two large crickets meet  [  50 2504] [0.01957713 0.98042287]
# Round 411 two large crickets meet  [  50 2510] [0.01953125 0.98046875]
# Round 412 two large crickets meet  [  50 2516] [0.01948558 0.98051442]
# Round 413 two large crickets meet  [  50 2522] [0.01944012 0.98055988]
# Round 414 two large crickets meet  [  50 2528] [0.01939488 0.98060512]
# Round 415 two large crickets meet  [  50 2534] [0.01934985 0.98065015]
# Round 416 two large crickets meet  [  50 2540] [0.01930502 0.98069498]
# Round 417 two large crickets meet  [  50 2546] [0.0192604 0.9807396]
# Round 418 two large crickets meet  [  50 2552] [0.01921599 0.98078401]
# Round 419 two large crickets meet  [  50 2558] [0.01917178 0.98082822]
# Round 420 two large crickets meet  [  50 2564] [0.01912777 0.98087223]
# Round 421 two large crickets meet  [  50 2570] [0.01908397 0.98091603]
# Round 422 two large crickets meet  [  50 2576] [0.01904037 0.98095963]
# Round 423 two large crickets meet  [  50 2582] [0.01899696 0.98100304]
# Round 424 two large crickets meet  [  50 2588] [0.01895375 0.98104625]
# Round 425 two large crickets meet  [  50 2594] [0.01891074 0.98108926]
# Round 426 two large crickets meet  [  50 2600] [0.01886792 0.98113208]
# Round 427 two large crickets meet  [  50 2606] [0.0188253 0.9811747]
# Round 428 two large crickets meet  [  50 2612] [0.01878287 0.98121713]
# Round 429 two large crickets meet  [  50 2618] [0.01874063 0.98125937]
# Round 430 two large crickets meet  [  50 2624] [0.01869858 0.98130142]
# Round 431 two large crickets meet  [  50 2630] [0.01865672 0.98134328]
# Round 432 two large crickets meet  [  50 2636] [0.01861504 0.98138496]
# Round 433 two large crickets meet  [  50 2642] [0.01857355 0.98142645]
# Round 434 two large crickets meet  [  50 2648] [0.01853225 0.98146775]
# Round 435 two large crickets meet  [  50 2654] [0.01849112 0.98150888]
# Round 436 two large crickets meet  [  50 2660] [0.01845018 0.98154982]
# Round 437 two large crickets meet  [  50 2666] [0.01840943 0.98159057]
# Round 438 two large crickets meet  [  50 2672] [0.01836885 0.98163115]
# Round 439 two large crickets meet  [  50 2678] [0.01832845 0.98167155]
# Round 440 a small meets a large    [  51 2686] [0.01863354 0.98136646]
# Round 441 two large crickets meet  [  51 2692] [0.01859278 0.98140722]
# Round 442 two large crickets meet  [  51 2698] [0.0185522 0.9814478]
# Round 443 two large crickets meet  [  51 2704] [0.0185118 0.9814882]
# Round 444 two large crickets meet  [  51 2710] [0.01847157 0.98152843]
# Round 445 two large crickets meet  [  51 2716] [0.01843151 0.98156849]
# Round 446 two large crickets meet  [  51 2722] [0.01839163 0.98160837]
# Round 447 two large crickets meet  [  51 2728] [0.01835193 0.98164807]
# Round 448 two large crickets meet  [  51 2734] [0.01831239 0.98168761]
# Round 449 a small meets a large    [  52 2742] [0.01861131 0.98138869]
# Round 450 two large crickets meet  [  52 2748] [0.01857143 0.98142857]
# Round 451 two large crickets meet  [  52 2754] [0.01853172 0.98146828]
# Round 452 two large crickets meet  [  52 2760] [0.01849218 0.98150782]
# Round 453 two large crickets meet  [  52 2766] [0.0184528 0.9815472]
# Round 454 two large crickets meet  [  52 2772] [0.0184136 0.9815864]
# Round 455 a small meets a large    [  53 2780] [0.01870808 0.98129192]
# Round 456 two large crickets meet  [  53 2786] [0.01866855 0.98133145]
# Round 457 two large crickets meet  [  53 2792] [0.01862917 0.98137083]
# Round 458 two large crickets meet  [  53 2798] [0.01858997 0.98141003]
# Round 459 two large crickets meet  [  53 2804] [0.01855093 0.98144907]
# Round 460 two large crickets meet  [  53 2810] [0.01851205 0.98148795]
# Round 461 two large crickets meet  [  53 2816] [0.01847334 0.98152666]
# Round 462 two large crickets meet  [  53 2822] [0.01843478 0.98156522]
# Round 463 two large crickets meet  [  53 2828] [0.01839639 0.98160361]
# Round 464 two large crickets meet  [  53 2834] [0.01835816 0.98164184]
# Round 465 two large crickets meet  [  53 2840] [0.01832008 0.98167992]
# Round 466 a small meets a large    [  54 2848] [0.01860786 0.98139214]
# Round 467 two large crickets meet  [  54 2854] [0.01856946 0.98143054]
# Round 468 two large crickets meet  [  54 2860] [0.01853123 0.98146877]
# Round 469 two large crickets meet  [  54 2866] [0.01849315 0.98150685]
# Round 470 two large crickets meet  [  54 2872] [0.01845523 0.98154477]
# Round 471 two large crickets meet  [  54 2878] [0.01841746 0.98158254]
# Round 472 two large crickets meet  [  54 2884] [0.01837985 0.98162015]
# Round 473 two large crickets meet  [  54 2890] [0.01834239 0.98165761]
# Round 474 two large crickets meet  [  54 2896] [0.01830508 0.98169492]
# Round 475 two large crickets meet  [  54 2902] [0.01826793 0.98173207]
# Round 476 two large crickets meet  [  54 2908] [0.01823093 0.98176907]
# Round 477 two large crickets meet  [  54 2914] [0.01819407 0.98180593]
# Round 478 two large crickets meet  [  54 2920] [0.01815736 0.98184264]
# Round 479 two large crickets meet  [  54 2926] [0.01812081 0.98187919]
# Round 480 two large crickets meet  [  54 2932] [0.01808439 0.98191561]
# Round 481 two large crickets meet  [  54 2938] [0.01804813 0.98195187]
# Round 482 two large crickets meet  [  54 2944] [0.01801201 0.98198799]
# Round 483 two large crickets meet  [  54 2950] [0.01797603 0.98202397]
# Round 484 two large crickets meet  [  54 2956] [0.0179402 0.9820598]
# Round 485 two large crickets meet  [  54 2962] [0.01790451 0.98209549]
# Round 486 two large crickets meet  [  54 2968] [0.01786896 0.98213104]
# Round 487 a small meets a large    [  55 2976] [0.01814583 0.98185417]
# Round 488 two large crickets meet  [  55 2982] [0.01810998 0.98189002]
# Round 489 two large crickets meet  [  55 2988] [0.01807427 0.98192573]
# Round 490 a small meets a large    [  56 2996] [0.01834862 0.98165138]
# Round 491 two large crickets meet  [  56 3002] [0.01831262 0.98168738]
# Round 492 two large crickets meet  [  56 3008] [0.01827676 0.98172324]
# Round 493 two large crickets meet  [  56 3014] [0.01824104 0.98175896]
# Round 494 two large crickets meet  [  56 3020] [0.01820546 0.98179454]
# Round 495 a small meets a large    [  57 3028] [0.0184765 0.9815235]
# Round 496 two large crickets meet  [  57 3034] [0.01844063 0.98155937]
# Round 497 two large crickets meet  [  57 3040] [0.01840491 0.98159509]
# Round 498 two large crickets meet  [  57 3046] [0.01836932 0.98163068]
# Round 499 two large crickets meet  [  57 3052] [0.01833387 0.98166613]
# Round 500 two large crickets meet  [  57 3058] [0.01829856 0.98170144]
# Round 501 two large crickets meet  [  57 3064] [0.01826338 0.98173662]
# Round 502 two large crickets meet  [  57 3070] [0.01822833 0.98177167]
# Round 503 two large crickets meet  [  57 3076] [0.01819342 0.98180658]
# Round 504 two large crickets meet  [  57 3082] [0.01815865 0.98184135]
# Round 505 two large crickets meet  [  57 3088] [0.01812401 0.98187599]
# Round 506 two large crickets meet  [  57 3094] [0.0180895 0.9819105]
# Round 507 two large crickets meet  [  57 3100] [0.01805512 0.98194488]
# Round 508 two large crickets meet  [  57 3106] [0.01802087 0.98197913]
# Round 509 two large crickets meet  [  57 3112] [0.01798675 0.98201325]
# Round 510 two large crickets meet  [  57 3118] [0.01795276 0.98204724]
# Round 511 two large crickets meet  [  57 3124] [0.01791889 0.98208111]
# Round 512 two large crickets meet  [  57 3130] [0.01788516 0.98211484]
# Round 513 two large crickets meet  [  57 3136] [0.01785155 0.98214845]
# Round 514 two large crickets meet  [  57 3142] [0.01781807 0.98218193]
# Round 515 two large crickets meet  [  57 3148] [0.01778471 0.98221529]
# Round 516 two large crickets meet  [  57 3154] [0.01775148 0.98224852]
# Round 517 two large crickets meet  [  57 3160] [0.01771837 0.98228163]
# Round 518 two large crickets meet  [  57 3166] [0.01768539 0.98231461]
# Round 519 two large crickets meet  [  57 3172] [0.01765252 0.98234748]
# Round 520 two large crickets meet  [  57 3178] [0.01761978 0.98238022]
# Round 521 two large crickets meet  [  57 3184] [0.01758716 0.98241284]
# Round 522 two large crickets meet  [  57 3190] [0.01755467 0.98244533]
# Round 523 two large crickets meet  [  57 3196] [0.01752229 0.98247771]
# Round 524 two large crickets meet  [  57 3202] [0.01749003 0.98250997]
# Round 525 two large crickets meet  [  57 3208] [0.01745789 0.98254211]
# Round 526 two large crickets meet  [  57 3214] [0.01742586 0.98257414]
# Round 527 two large crickets meet  [  57 3220] [0.01739396 0.98260604]
# Round 528 two large crickets meet  [  57 3226] [0.01736217 0.98263783]
# Round 529 two large crickets meet  [  57 3232] [0.0173305 0.9826695]
# Round 530 two large crickets meet  [  57 3238] [0.01729894 0.98270106]
# Round 531 two large crickets meet  [  57 3244] [0.01726749 0.98273251]
# Round 532 two large crickets meet  [  57 3250] [0.01723617 0.98276383]
# Round 533 two large crickets meet  [  57 3256] [0.01720495 0.98279505]
# Round 534 two large crickets meet  [  57 3262] [0.01717385 0.98282615]
# Round 535 two large crickets meet  [  57 3268] [0.01714286 0.98285714]
# Round 536 two large crickets meet  [  57 3274] [0.01711198 0.98288802]
# Round 537 two large crickets meet  [  57 3280] [0.01708121 0.98291879]
# Round 538 two large crickets meet  [  57 3286] [0.01705055 0.98294945]
# Round 539 two large crickets meet  [  57 3292] [0.01702001 0.98297999]
# Round 540 two large crickets meet  [  57 3298] [0.01698957 0.98301043]
# Round 541 two large crickets meet  [  57 3304] [0.01695924 0.98304076]
# Round 542 a small meets a large    [  58 3312] [0.01721068 0.98278932]
# Round 543 two large crickets meet  [  58 3318] [0.01718009 0.98281991]
# Round 544 two large crickets meet  [  58 3324] [0.01714962 0.98285038]
# Round 545 two large crickets meet  [  58 3330] [0.01711924 0.98288076]
# Round 546 two large crickets meet  [  58 3336] [0.01708898 0.98291102]
# Round 547 two large crickets meet  [  58 3342] [0.01705882 0.98294118]
# Round 548 two large crickets meet  [  58 3348] [0.01702877 0.98297123]
# Round 549 two large crickets meet  [  58 3354] [0.01699883 0.98300117]
# Round 550 two large crickets meet  [  58 3360] [0.01696899 0.98303101]
# Round 551 two large crickets meet  [  58 3366] [0.01693925 0.98306075]
# Round 552 two large crickets meet  [  58 3372] [0.01690962 0.98309038]
# Round 553 two large crickets meet  [  58 3378] [0.01688009 0.98311991]
# Round 554 a small meets a large    [  59 3386] [0.01712627 0.98287373]
# Round 555 two large crickets meet  [  59 3392] [0.01709649 0.98290351]
# Round 556 two large crickets meet  [  59 3398] [0.01706682 0.98293318]
# Round 557 two large crickets meet  [  59 3404] [0.01703725 0.98296275]
# Round 558 two large crickets meet  [  59 3410] [0.01700778 0.98299222]
# Round 559 two large crickets meet  [  59 3416] [0.01697842 0.98302158]
# Round 560 two large crickets meet  [  59 3422] [0.01694915 0.98305085]
# Round 561 two large crickets meet  [  59 3428] [0.01691999 0.98308001]
# Round 562 two large crickets meet  [  59 3434] [0.01689092 0.98310908]
# Round 563 two large crickets meet  [  59 3440] [0.01686196 0.98313804]
# Round 564 two large crickets meet  [  59 3446] [0.0168331 0.9831669]
# Round 565 two large crickets meet  [  59 3452] [0.01680433 0.98319567]
# Round 566 two large crickets meet  [  59 3458] [0.01677566 0.98322434]
# Round 567 two large crickets meet  [  59 3464] [0.01674709 0.98325291]
# Round 568 two large crickets meet  [  59 3470] [0.01671862 0.98328138]
# Round 569 two large crickets meet  [  59 3476] [0.01669024 0.98330976]
# Round 570 two large crickets meet  [  59 3482] [0.01666196 0.98333804]
# Round 571 two large crickets meet  [  59 3488] [0.01663378 0.98336622]
# Round 572 two large crickets meet  [  59 3494] [0.01660569 0.98339431]
# Round 573 two large crickets meet  [  59 3500] [0.01657769 0.98342231]
# Round 574 two large crickets meet  [  59 3506] [0.01654979 0.98345021]
# Round 575 two large crickets meet  [  59 3512] [0.01652198 0.98347802]
# Round 576 two large crickets meet  [  59 3518] [0.01649427 0.98350573]
# Round 577 two large crickets meet  [  59 3524] [0.01646665 0.98353335]
# Round 578 two large crickets meet  [  59 3530] [0.01643912 0.98356088]
# Round 579 two large crickets meet  [  59 3536] [0.01641168 0.98358832]
# Round 580 two large crickets meet  [  59 3542] [0.01638434 0.98361566]
# Round 581 two large crickets meet  [  59 3548] [0.01635708 0.98364292]
# Round 582 two large crickets meet  [  59 3554] [0.01632992 0.98367008]
# Round 583 two large crickets meet  [  59 3560] [0.01630285 0.98369715]
# Round 584 two large crickets meet  [  59 3566] [0.01627586 0.98372414]
# Round 585 two large crickets meet  [  59 3572] [0.01624897 0.98375103]
# Round 586 two large crickets meet  [  59 3578] [0.01622216 0.98377784]
# Round 587 two large crickets meet  [  59 3584] [0.01619544 0.98380456]
# Round 588 two large crickets meet  [  59 3590] [0.01616881 0.98383119]
# Round 589 two large crickets meet  [  59 3596] [0.01614227 0.98385773]
# Round 590 two large crickets meet  [  59 3602] [0.01611582 0.98388418]
# Round 591 two large crickets meet  [  59 3608] [0.01608945 0.98391055]
# Round 592 two large crickets meet  [  59 3614] [0.01606316 0.98393684]
# Round 593 two large crickets meet  [  59 3620] [0.01603697 0.98396303]
# Round 594 two large crickets meet  [  59 3626] [0.01601085 0.98398915]
# Round 595 two large crickets meet  [  59 3632] [0.01598483 0.98401517]
# Round 596 two large crickets meet  [  59 3638] [0.01595889 0.98404111]
# Round 597 two large crickets meet  [  59 3644] [0.01593303 0.98406697]
# Round 598 two large crickets meet  [  59 3650] [0.01590725 0.98409275]
# Round 599 two large crickets meet  [  59 3656] [0.01588156 0.98411844]
# Round 600 two large crickets meet  [  59 3662] [0.01585595 0.98414405]
# Round 601 two large crickets meet  [  59 3668] [0.01583043 0.98416957]
# Round 602 two large crickets meet  [  59 3674] [0.01580498 0.98419502]
# Round 603 two large crickets meet  [  59 3680] [0.01577962 0.98422038]
# Round 604 two large crickets meet  [  59 3686] [0.01575434 0.98424566]
# Round 605 two large crickets meet  [  59 3692] [0.01572914 0.98427086]
# Round 606 two large crickets meet  [  59 3698] [0.01570402 0.98429598]
# Round 607 two large crickets meet  [  59 3704] [0.01567898 0.98432102]
# Round 608 two large crickets meet  [  59 3710] [0.01565402 0.98434598]
# Round 609 two large crickets meet  [  59 3716] [0.01562914 0.98437086]
# Round 610 two large crickets meet  [  59 3722] [0.01560434 0.98439566]
# Round 611 two large crickets meet  [  59 3728] [0.01557961 0.98442039]
# Round 612 two large crickets meet  [  59 3734] [0.01555497 0.98444503]
# Round 613 two large crickets meet  [  59 3740] [0.0155304 0.9844696]
# Round 614 two large crickets meet  [  59 3746] [0.01550591 0.98449409]
# Round 615 two large crickets meet  [  59 3752] [0.0154815 0.9845185]
# Round 616 two large crickets meet  [  59 3758] [0.01545717 0.98454283]
# Round 617 two large crickets meet  [  59 3764] [0.01543291 0.98456709]
# Round 618 two large crickets meet  [  59 3770] [0.01540872 0.98459128]
# Round 619 two large crickets meet  [  59 3776] [0.01538462 0.98461538]
# Round 620 two large crickets meet  [  59 3782] [0.01536058 0.98463942]
# Round 621 two large crickets meet  [  59 3788] [0.01533663 0.98466337]
# Round 622 two large crickets meet  [  59 3794] [0.01531274 0.98468726]
# Round 623 two large crickets meet  [  59 3800] [0.01528893 0.98471107]
# Round 624 two large crickets meet  [  59 3806] [0.0152652 0.9847348]
# Round 625 two large crickets meet  [  59 3812] [0.01524154 0.98475846]
# Round 626 two large crickets meet  [  59 3818] [0.01521795 0.98478205]
# Round 627 two large crickets meet  [  59 3824] [0.01519444 0.98480556]
# Round 628 two large crickets meet  [  59 3830] [0.015171 0.984829]
# Round 629 two large crickets meet  [  59 3836] [0.01514763 0.98485237]
# Round 630 two large crickets meet  [  59 3842] [0.01512433 0.98487567]
# Round 631 two large crickets meet  [  59 3848] [0.0151011 0.9848989]
# Round 632 two large crickets meet  [  59 3854] [0.01507795 0.98492205]
# Round 633 two large crickets meet  [  59 3860] [0.01505486 0.98494514]
# Round 634 two large crickets meet  [  59 3866] [0.01503185 0.98496815]
# Round 635 two large crickets meet  [  59 3872] [0.0150089 0.9849911]
# Round 636 two large crickets meet  [  59 3878] [0.01498603 0.98501397]
# Round 637 two large crickets meet  [  59 3884] [0.01496323 0.98503677]
# Round 638 two large crickets meet  [  59 3890] [0.01494049 0.98505951]
# Round 639 two large crickets meet  [  59 3896] [0.01491783 0.98508217]
# Round 640 two large crickets meet  [  59 3902] [0.01489523 0.98510477]
# Round 641 two large crickets meet  [  59 3908] [0.0148727 0.9851273]
# Round 642 two large crickets meet  [  59 3914] [0.01485024 0.98514976]
# Round 643 two large crickets meet  [  59 3920] [0.01482785 0.98517215]
# Round 644 two large crickets meet  [  59 3926] [0.01480552 0.98519448]
# Round 645 two large crickets meet  [  59 3932] [0.01478326 0.98521674]
# Round 646 two large crickets meet  [  59 3938] [0.01476107 0.98523893]
# Round 647 two large crickets meet  [  59 3944] [0.01473895 0.98526105]
# Round 648 two large crickets meet  [  59 3950] [0.01471689 0.98528311]
# Round 649 two large crickets meet  [  59 3956] [0.01469489 0.98530511]
# Round 650 two large crickets meet  [  59 3962] [0.01467297 0.98532703]
# Round 651 two large crickets meet  [  59 3968] [0.01465111 0.98534889]
# Round 652 two large crickets meet  [  59 3974] [0.01462931 0.98537069]
# Round 653 two large crickets meet  [  59 3980] [0.01460758 0.98539242]
# Round 654 two large crickets meet  [  59 3986] [0.01458591 0.98541409]
# Round 655 two large crickets meet  [  59 3992] [0.01456431 0.98543569]
# Round 656 two large crickets meet  [  59 3998] [0.01454277 0.98545723]
# Round 657 two large crickets meet  [  59 4004] [0.01452129 0.98547871]
# Round 658 two large crickets meet  [  59 4010] [0.01449988 0.98550012]
# Round 659 two large crickets meet  [  59 4016] [0.01447853 0.98552147]
# Round 660 two large crickets meet  [  59 4022] [0.01445724 0.98554276]
# Round 661 two large crickets meet  [  59 4028] [0.01443602 0.98556398]
# Round 662 two large crickets meet  [  59 4034] [0.01441485 0.98558515]
# Round 663 two large crickets meet  [  59 4040] [0.01439375 0.98560625]
# Round 664 two large crickets meet  [  59 4046] [0.01437272 0.98562728]
# Round 665 two large crickets meet  [  59 4052] [0.01435174 0.98564826]
# Round 666 two large crickets meet  [  59 4058] [0.01433082 0.98566918]
# Round 667 two large crickets meet  [  59 4064] [0.01430997 0.98569003]
# Round 668 two large crickets meet  [  59 4070] [0.01428917 0.98571083]
# Round 669 two large crickets meet  [  59 4076] [0.01426844 0.98573156]
# Round 670 two large crickets meet  [  59 4082] [0.01424777 0.98575223]
# Round 671 two large crickets meet  [  59 4088] [0.01422715 0.98577285]
# Round 672 two large crickets meet  [  59 4094] [0.0142066 0.9857934]
# Round 673 two large crickets meet  [  59 4100] [0.0141861 0.9858139]
# Round 674 two large crickets meet  [  59 4106] [0.01416567 0.98583433]
# Round 675 two large crickets meet  [  59 4112] [0.01414529 0.98585471]
# Round 676 two large crickets meet  [  59 4118] [0.01412497 0.98587503]
# Round 677 a small meets a large    [  60 4126] [0.01433349 0.98566651]
# Round 678 two large crickets meet  [  60 4132] [0.01431298 0.98568702]
# Round 679 two large crickets meet  [  60 4138] [0.01429252 0.98570748]
# Round 680 two large crickets meet  [  60 4144] [0.01427212 0.98572788]
# Round 681 two large crickets meet  [  60 4150] [0.01425178 0.98574822]
# Round 682 two large crickets meet  [  60 4156] [0.0142315 0.9857685]
# Round 683 two large crickets meet  [  60 4162] [0.01421127 0.98578873]
# ...
# Round 775 two large crickets meet  [  62 4718] [0.01297071 0.98702929]
# Round 776 two large crickets meet  [  62 4724] [0.01295445 0.98704555]
# Round 777 two large crickets meet  [  62 4730] [0.01293823 0.98706177]
# Round 778 two large crickets meet  [  62 4736] [0.01292205 0.98707795]
# Round 779 two large crickets meet  [  62 4742] [0.01290591 0.98709409]
# Round 780 two large crickets meet  [  62 4748] [0.01288981 0.98711019]
# Round 781 a small meets a large    [  63 4756] [0.01307325 0.98692675]
# Round 782 two large crickets meet  [  63 4762] [0.01305699 0.98694301]
# Round 783 two large crickets meet  [  63 4768] [0.01304078 0.98695922]
# Round 784 two large crickets meet  [  63 4774] [0.0130246 0.9869754]
# Round 785 two large crickets meet  [  63 4780] [0.01300847 0.98699153]
# Round 786 two large crickets meet  [  63 4786] [0.01299237 0.98700763]
# Round 787 two large crickets meet  [  63 4792] [0.01297631 0.98702369]
# Round 788 two large crickets meet  [  63 4798] [0.0129603 0.9870397]
# Round 789 two large crickets meet  [  63 4804] [0.01294432 0.98705568]
# Round 790 two large crickets meet  [  63 4810] [0.01292838 0.98707162]
# Round 791 two large crickets meet  [  63 4816] [0.01291248 0.98708752]
# Round 792 two large crickets meet  [  63 4822] [0.01289662 0.98710338]
# Round 793 two large crickets meet  [  63 4828] [0.0128808 0.9871192]
# Round 794 two large crickets meet  [  63 4834] [0.01286502 0.98713498]
# Round 795 two large crickets meet  [  63 4840] [0.01284928 0.98715072]
# Round 796 two large crickets meet  [  63 4846] [0.01283357 0.98716643]
# Round 797 two large crickets meet  [  63 4852] [0.0128179 0.9871821]
# Round 798 two large crickets meet  [  63 4858] [0.01280228 0.98719772]
# Round 799 two large crickets meet  [  63 4864] [0.01278669 0.98721331]
# Round 800 two large crickets meet  [  63 4870] [0.01277113 0.98722887]
# Round 801 two large crickets meet  [  63 4876] [0.01275562 0.98724438]
# Round 802 two large crickets meet  [  63 4882] [0.01274014 0.98725986]
# Round 803 two large crickets meet  [  63 4888] [0.0127247 0.9872753]
# Round 804 two large crickets meet  [  63 4894] [0.0127093 0.9872907]
# Round 805 two large crickets meet  [  63 4900] [0.01269394 0.98730606]
# Round 806 two large crickets meet  [  63 4906] [0.01267861 0.98732139]
# Round 807 two large crickets meet  [  63 4912] [0.01266332 0.98733668]
# Round 808 two large crickets meet  [  63 4918] [0.01264806 0.98735194]
# Round 809 two large crickets meet  [  63 4924] [0.01263285 0.98736715]
# Round 810 two large crickets meet  [  63 4930] [0.01261766 0.98738234]
# Round 811 two large crickets meet  [  63 4936] [0.01260252 0.98739748]
# Round 812 two large crickets meet  [  63 4942] [0.01258741 0.98741259]
# Round 813 two large crickets meet  [  63 4948] [0.01257234 0.98742766]
# Round 814 two large crickets meet  [  63 4954] [0.01255731 0.98744269]
# Round 815 two large crickets meet  [  63 4960] [0.01254231 0.98745769]
# Round 816 two large crickets meet  [  63 4966] [0.01252734 0.98747266]
# Round 817 a small meets a large    [  64 4974] [0.01270345 0.98729655]
# Round 818 two large crickets meet  [  64 4980] [0.01268834 0.98731166]
# Round 819 two large crickets meet  [  64 4986] [0.01267327 0.98732673]
# Round 820 two large crickets meet  [  64 4992] [0.01265823 0.98734177]
# Round 821 two large crickets meet  [  64 4998] [0.01264322 0.98735678]
# Round 822 two large crickets meet  [  64 5004] [0.01262826 0.98737174]
# Round 823 two large crickets meet  [  64 5010] [0.01261332 0.98738668]
# Round 824 two large crickets meet  [  64 5016] [0.01259843 0.98740157]
# Round 825 two large crickets meet  [  64 5022] [0.01258356 0.98741644]
# Round 826 two large crickets meet  [  64 5028] [0.01256874 0.98743126]
# Round 827 two large crickets meet  [  64 5034] [0.01255394 0.98744606]
# Round 828 two large crickets meet  [  64 5040] [0.01253918 0.98746082]
# Round 829 two large crickets meet  [  64 5046] [0.01252446 0.98747554]
# Round 830 two large crickets meet  [  64 5052] [0.01250977 0.98749023]
# Round 831 two large crickets meet  [  64 5058] [0.01249512 0.98750488]
# Round 832 two large crickets meet  [  64 5064] [0.0124805 0.9875195]
# Round 833 two large crickets meet  [  64 5070] [0.01246591 0.98753409]
# Round 834 two large crickets meet  [  64 5076] [0.01245136 0.98754864]
# Round 835 two large crickets meet  [  64 5082] [0.01243684 0.98756316]
# Round 836 two large crickets meet  [  64 5088] [0.01242236 0.98757764]
# Round 837 two large crickets meet  [  64 5094] [0.01240791 0.98759209]
# Round 838 two large crickets meet  [  64 5100] [0.01239349 0.98760651]
# Round 839 two large crickets meet  [  64 5106] [0.01237911 0.98762089]
# Round 840 two large crickets meet  [  64 5112] [0.01236476 0.98763524]
# Round 841 two large crickets meet  [  64 5118] [0.01235044 0.98764956]
# Round 842 two large crickets meet  [  64 5124] [0.01233616 0.98766384]
# Round 843 two large crickets meet  [  64 5130] [0.01232191 0.98767809]
# Round 844 two large crickets meet  [  64 5136] [0.01230769 0.98769231]
# Round 845 two large crickets meet  [  64 5142] [0.01229351 0.98770649]
# Round 846 two large crickets meet  [  64 5148] [0.01227936 0.98772064]
# Round 847 two large crickets meet  [  64 5154] [0.01226524 0.98773476]
# Round 848 two large crickets meet  [  64 5160] [0.01225115 0.98774885]
# Round 849 two large crickets meet  [  64 5166] [0.01223709 0.98776291]
# Round 850 two large crickets meet  [  64 5172] [0.01222307 0.98777693]
# Round 851 two large crickets meet  [  64 5178] [0.01220908 0.98779092]
# Round 852 two large crickets meet  [  64 5184] [0.01219512 0.98780488]
# Round 853 two large crickets meet  [  64 5190] [0.0121812 0.9878188]
# Round 854 two large crickets meet  [  64 5196] [0.0121673 0.9878327]
# Round 855 two large crickets meet  [  64 5202] [0.01215344 0.98784656]
# Round 856 two large crickets meet  [  64 5208] [0.01213961 0.98786039]
# Round 857 two large crickets meet  [  64 5214] [0.01212581 0.98787419]
# Round 858 two large crickets meet  [  64 5220] [0.01211204 0.98788796]
# Round 859 two large crickets meet  [  64 5226] [0.0120983 0.9879017]
# Round 860 two large crickets meet  [  64 5232] [0.01208459 0.98791541]
# Round 861 two large crickets meet  [  64 5238] [0.01207092 0.98792908]
# Round 862 two large crickets meet  [  64 5244] [0.01205727 0.98794273]
# Round 863 two large crickets meet  [  64 5250] [0.01204366 0.98795634]
# Round 864 two large crickets meet  [  64 5256] [0.01203008 0.98796992]
# Round 865 two large crickets meet  [  64 5262] [0.01201652 0.98798348]
# Round 866 two large crickets meet  [  64 5268] [0.012003 0.987997]
# Round 867 two large crickets meet  [  64 5274] [0.01198951 0.98801049]
# Round 868 two large crickets meet  [  64 5280] [0.01197605 0.98802395]
# Round 869 two large crickets meet  [  64 5286] [0.01196262 0.98803738]
# Round 870 two large crickets meet  [  64 5292] [0.01194922 0.98805078]
# Round 871 two large crickets meet  [  64 5298] [0.01193584 0.98806416]
# Round 872 two large crickets meet  [  64 5304] [0.0119225 0.9880775]
# Round 873 two large crickets meet  [  64 5310] [0.01190919 0.98809081]
# Round 874 two large crickets meet  [  64 5316] [0.01189591 0.98810409]
# Round 875 two large crickets meet  [  64 5322] [0.01188266 0.98811734]
# Round 876 two large crickets meet  [  64 5328] [0.01186944 0.98813056]
# Round 877 two large crickets meet  [  64 5334] [0.01185624 0.98814376]
# Round 878 two large crickets meet  [  64 5340] [0.01184308 0.98815692]
# Round 879 two large crickets meet  [  64 5346] [0.01182994 0.98817006]
# Round 880 two large crickets meet  [  64 5352] [0.01181684 0.98818316]
# Round 881 two large crickets meet  [  64 5358] [0.01180376 0.98819624]
# Round 882 two large crickets meet  [  64 5364] [0.01179071 0.98820929]
# Round 883 two large crickets meet  [  64 5370] [0.0117777 0.9882223]
# Round 884 two large crickets meet  [  64 5376] [0.01176471 0.98823529]
# Round 885 two large crickets meet  [  64 5382] [0.01175174 0.98824826]
# Round 886 two large crickets meet  [  64 5388] [0.01173881 0.98826119]
# Round 887 two large crickets meet  [  64 5394] [0.01172591 0.98827409]
# Round 888 two large crickets meet  [  64 5400] [0.01171303 0.98828697]
# Round 889 two large crickets meet  [  64 5406] [0.01170018 0.98829982]
# Round 890 two large crickets meet  [  64 5412] [0.01168736 0.98831264]
# Round 891 two large crickets meet  [  64 5418] [0.01167457 0.98832543]
# Round 892 two large crickets meet  [  64 5424] [0.01166181 0.98833819]
# Round 893 two large crickets meet  [  64 5430] [0.01164907 0.98835093]
# Round 894 two large crickets meet  [  64 5436] [0.01163636 0.98836364]
# Round 895 two large crickets meet  [  64 5442] [0.01162368 0.98837632]
# Round 896 two large crickets meet  [  64 5448] [0.01161103 0.98838897]
# Round 897 two large crickets meet  [  64 5454] [0.01159841 0.98840159]
# Round 898 two large crickets meet  [  64 5460] [0.01158581 0.98841419]
# Round 899 two large crickets meet  [  64 5466] [0.01157324 0.98842676]
# Round 900 two large crickets meet  [  64 5472] [0.01156069 0.98843931]
# Round 901 two large crickets meet  [  64 5478] [0.01154818 0.98845182]
# Round 902 two large crickets meet  [  64 5484] [0.01153569 0.98846431]
# Round 903 two large crickets meet  [  64 5490] [0.01152323 0.98847677]
# Round 904 two large crickets meet  [  64 5496] [0.01151079 0.98848921]
# Round 905 two large crickets meet  [  64 5502] [0.01149838 0.98850162]
# Round 906 two large crickets meet  [  64 5508] [0.011486 0.988514]
# Round 907 two large crickets meet  [  64 5514] [0.01147365 0.98852635]
# Round 908 two large crickets meet  [  64 5520] [0.01146132 0.98853868]
# Round 909 two large crickets meet  [  64 5526] [0.01144902 0.98855098]
# Round 910 two large crickets meet  [  64 5532] [0.01143674 0.98856326]
# Round 911 two large crickets meet  [  64 5538] [0.01142449 0.98857551]
# Round 912 two large crickets meet  [  64 5544] [0.01141227 0.98858773]
# Round 913 two large crickets meet  [  64 5550] [0.01140007 0.98859993]
# Round 914 two large crickets meet  [  64 5556] [0.0113879 0.9886121]
# Round 915 two large crickets meet  [  64 5562] [0.01137576 0.98862424]
# Round 916 two large crickets meet  [  64 5568] [0.01136364 0.98863636]
# Round 917 two large crickets meet  [  64 5574] [0.01135154 0.98864846]
# Round 918 two large crickets meet  [  64 5580] [0.01133948 0.98866052]
# Round 919 two large crickets meet  [  64 5586] [0.01132743 0.98867257]
# Round 920 two large crickets meet  [  64 5592] [0.01131542 0.98868458]
# Round 921 two large crickets meet  [  64 5598] [0.01130343 0.98869657]
# Round 922 two large crickets meet  [  64 5604] [0.01129146 0.98870854]
# Round 923 two large crickets meet  [  64 5610] [0.01127952 0.98872048]
# Round 924 two large crickets meet  [  64 5616] [0.01126761 0.98873239]
# Round 925 two large crickets meet  [  64 5622] [0.01125572 0.98874428]
# Round 926 two large crickets meet  [  64 5628] [0.01124385 0.98875615]
# Round 927 two large crickets meet  [  64 5634] [0.01123201 0.98876799]
# Round 928 two large crickets meet  [  64 5640] [0.0112202 0.9887798]
# Round 929 two large crickets meet  [  64 5646] [0.01120841 0.98879159]
# Round 930 two large crickets meet  [  64 5652] [0.01119664 0.98880336]
# Round 931 two large crickets meet  [  64 5658] [0.0111849 0.9888151]
# Round 932 two large crickets meet  [  64 5664] [0.01117318 0.98882682]
# Round 933 two large crickets meet  [  64 5670] [0.01116149 0.98883851]
# Round 934 two large crickets meet  [  64 5676] [0.01114983 0.98885017]
# Round 935 two large crickets meet  [  64 5682] [0.01113818 0.98886182]
# Round 936 two large crickets meet  [  64 5688] [0.01112656 0.98887344]
# Round 937 two large crickets meet  [  64 5694] [0.01111497 0.98888503]
# Round 938 two large crickets meet  [  64 5700] [0.0111034 0.9888966]
# Round 939 two large crickets meet  [  64 5706] [0.01109185 0.98890815]
# Round 940 two large crickets meet  [  64 5712] [0.01108033 0.98891967]
# Round 941 two large crickets meet  [  64 5718] [0.01106883 0.98893117]
# Round 942 two large crickets meet  [  64 5724] [0.01105736 0.98894264]
# Round 943 two large crickets meet  [  64 5730] [0.01104591 0.98895409]
# Round 944 two large crickets meet  [  64 5736] [0.01103448 0.98896552]
# Round 945 two large crickets meet  [  64 5742] [0.01102308 0.98897692]
# Round 946 two large crickets meet  [  64 5748] [0.0110117 0.9889883]
# Round 947 two large crickets meet  [  64 5754] [0.01100034 0.98899966]
# Round 948 two large crickets meet  [  64 5760] [0.01098901 0.98901099]
# Round 949 two large crickets meet  [  64 5766] [0.0109777 0.9890223]
# Round 950 two large crickets meet  [  64 5772] [0.01096642 0.98903358]
# Round 951 two large crickets meet  [  64 5778] [0.01095515 0.98904485]
# Round 952 two large crickets meet  [  64 5784] [0.01094391 0.98905609]
# Round 953 two large crickets meet  [  64 5790] [0.0109327 0.9890673]
# Round 954 two large crickets meet  [  64 5796] [0.0109215 0.9890785]
# Round 955 two large crickets meet  [  64 5802] [0.01091033 0.98908967]
# Round 956 two large crickets meet  [  64 5808] [0.01089918 0.98910082]
# Round 957 two large crickets meet  [  64 5814] [0.01088806 0.98911194]
# Round 958 two large crickets meet  [  64 5820] [0.01087695 0.98912305]
# Round 959 two large crickets meet  [  64 5826] [0.01086587 0.98913413]
# Round 960 two large crickets meet  [  64 5832] [0.01085482 0.98914518]
# Round 961 two large crickets meet  [  64 5838] [0.01084378 0.98915622]
# Round 962 two large crickets meet  [  64 5844] [0.01083277 0.98916723]
# Round 963 two large crickets meet  [  64 5850] [0.01082178 0.98917822]
# Round 964 two large crickets meet  [  64 5856] [0.01081081 0.98918919]
# Round 965 two large crickets meet  [  64 5862] [0.01079987 0.98920013]
# Round 966 two large crickets meet  [  64 5868] [0.01078894 0.98921106]
# Round 967 two large crickets meet  [  64 5874] [0.01077804 0.98922196]
# Round 968 two large crickets meet  [  64 5880] [0.01076716 0.98923284]
# Round 969 two large crickets meet  [  64 5886] [0.0107563 0.9892437]
# Round 970 two large crickets meet  [  64 5892] [0.01074547 0.98925453]
# Round 971 two large crickets meet  [  64 5898] [0.01073465 0.98926535]
# Round 972 two large crickets meet  [  64 5904] [0.01072386 0.98927614]
# Round 973 two large crickets meet  [  64 5910] [0.01071309 0.98928691]
# Round 974 two large crickets meet  [  64 5916] [0.01070234 0.98929766]
# Round 975 two large crickets meet  [  64 5922] [0.01069161 0.98930839]
# Round 976 two large crickets meet  [  64 5928] [0.01068091 0.98931909]
# Round 977 two large crickets meet  [  64 5934] [0.01067022 0.98932978]
# Round 978 two large crickets meet  [  64 5940] [0.01065956 0.98934044]
# Round 979 two large crickets meet  [  64 5946] [0.01064892 0.98935108]
# Round 980 two large crickets meet  [  64 5952] [0.0106383 0.9893617]
# Round 981 two large crickets meet  [  64 5958] [0.0106277 0.9893723]
# Round 982 two large crickets meet  [  64 5964] [0.01061712 0.98938288]
# Round 983 two large crickets meet  [  64 5970] [0.01060656 0.98939344]
# Round 984 two large crickets meet  [  64 5976] [0.01059603 0.98940397]
# Round 985 two large crickets meet  [  64 5982] [0.01058551 0.98941449]
# Round 986 two large crickets meet  [  64 5988] [0.01057502 0.98942498]
# Round 987 two large crickets meet  [  64 5994] [0.01056454 0.98943546]
# Round 988 two large crickets meet  [  64 6000] [0.01055409 0.98944591]
# Round 989 two large crickets meet  [  64 6006] [0.01054366 0.98945634]
# Round 990 two large crickets meet  [  64 6012] [0.01053325 0.98946675]
# Round 991 two large crickets meet  [  64 6018] [0.01052285 0.98947715]
# Round 992 two large crickets meet  [  64 6024] [0.01051248 0.98948752]
# Round 993 two large crickets meet  [  64 6030] [0.01050213 0.98949787]
# Round 994 two large crickets meet  [  64 6036] [0.0104918 0.9895082]
# Round 995 two large crickets meet  [  64 6042] [0.01048149 0.98951851]
# Round 996 two large crickets meet  [  64 6048] [0.0104712 0.9895288]
# Round 997 a small meets a large    [  65 6056] [0.01061918 0.98938082]
# Round 998 two large crickets meet  [  65 6062] [0.01060878 0.98939122]
# Round 999 two large crickets meet  [  65 6068] [0.0105984 0.9894016]
# Round 1000 two large crickets meet  [  65 6074] [0.01058804 0.98941196]

# %% [markdown]
# The above simulation displays, after each encounter, the number of individuals of each type and the fraction of individuals of each type.   Run the simulation multiple times for different initial conditions.
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 2:</SPAN>**  Answer the following questions.   You do not need to provide code for this problem, but explain your answers.
# <ol>
# <li> How quickly does the total population grow if initally all the crickets are small?
# <li> How quickly does the total population grow if initally all the crickets are large?
# <li> Do the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero? (To explore convergence you may need to increase the number of encounters simulated.)
# </ol>

# %% [markdown]
# __Answer:__
#
# __A1:__ If initally all the crickets are small, only two small crickets will meet each other in an encounter. Therefore, only ten small crikets will be spawned in each encounter. As a result, the total population growth rate is ten small crickets per encounter.
#
# __A2:__ If initally all the crickets are large, only two large crickets will meet each other in an encounter. Therefore, only six large crikets will be spawned in each encounter. As a result, the total population growth rate is six large crickets per encounter.
#
# __A3:__ Yes, the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 2</SPAN>**

# %% [markdown]
# The code given next is essentially the same as above.  One difference is a time variable is added such that the average rate that an individual cricket has encounters is proportional to the total number of crickets.  This results in exponential growth of the population with time.    Another difference is that population sizes are saved and plotted.

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted

F=np.array([[5,1],[8,3]])  # fitness matrix
n_max=100  # maximum number of interactions
n=np.zeros((n_max,2),dtype=float)
time=np.zeros(n_max,dtype=float)

n[0,0], n[0,1] = 4,4 # initial [number of small crickets, number of large crickets]

for k in range(n_max-1):
    time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
    a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
    b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n[k+1,:]= n[k,:] + [2*F[0,0],0]
    elif a<U<=a+b:
        n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
    else:
        n[k+1,:]= n[k,:] + [0,2*F[1,1]]

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.text(1.1,n[80,0], r'small',fontsize=14)
plt.text(1.1,n[80,1], r'large',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (simulation)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (simulation)')

# %% [markdown]
# The following code computes the __deterministic__ analog of the cricket evolution.  The basic idea is that if the current population is [n[0], n[1]] then the drift (i.e. the expected rate of increase) of n[0] is n[0]  multiplied by the expected number of small crickets generated by a small cricket if an encounter happens.  That is true because each of the existing small crikets is having encounters at expected rate one.   To calculate the mean number of new small crickets generated by the encounter of a small cricket with a randomly selected other cricket, we use the law of total probability.  The encountered cricket is type zero with probabiity n[0]/(n[0]+n[1]), which results in F[0,0] new crickets of type zero, and the encountered cricket is type one with probability n[1]/(n[0]+n[1]), which results in F[0,1] new crickets of type zero.   Combining we get
# $$
# \dot{n}[0] = n[0]*(F[0,0]*n[0]+F[0,1]*n[1])/(n[0]+n[1])
# $$
# The equation just derived is based on the law of large numbers (LLN).  If the population is fairly large then no one individual plays a major role in the evolution.  Over a small period of time the ratios of small and large crickets is nearly constant, so the number of new crickets of each type in each time slot are nearly independent and identically distributed.   The LLN suggests approximating the sum of number of individuals of each type by the expected numbers of individuals of each type.  That's how we arrive at a deterministic differential equation.
#
# A similar expression holds for the derivative of n[1], and the two equations can be writen in matrix form as
# $$
# \dot{n} = diag(n)*F*n/sum(n)
# $$
# where diag(n) is the diagonal matrix with n[0] and n[1] on the diagonal, and "$*$" represents usual matrix multiplication.   (In the python code below, "$*$" denotes element by element multiplication, which is used instead of creating a diagonal matrix, and np.dot is used for ordinary matrix multiplication.)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")
# Out:
# Text(0.5, 1.0, 'Numbers of small and large crickets vs. time (ode prediction)')

# %% [markdown]
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 3:</SPAN>** Run the code above and compare the output to the output of the previous code for stochastic evolutionary dynamics.  Try different intial conditions such as [0,4], [4,0], and [10,1]. Comment on how the result of this compares to our previous simulation. Is the behavior similar?

# %% [markdown]
# __Answer:__ It seems that whether the behavior is similar or not depends on the initial condition. For initial conditions like $[0,4]$ and $[4,0]$, the behavior is similar. In my opinion, initial conditions like $[0,4]$ and $[4,0]$ fix the type of crickets that can meet, so the random and the deterministic methods give similar results. However, for initial conditions, like $[10,1]$, which cannot fix the type of crickets that can meet, randomness comes into play. Since the random method is affected by randomness, the behavior is not similar.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 3</SPAN>**

# %% [markdown]
# If we let $\theta[0]=\frac{n[0]}{n[0]+n[1]}$ and $\theta[1]=\frac{n[1]}{n[0]+n[1]}$ then the vector $\theta=\binom{\theta[0]}{\theta[1]}$ describes the fractions of the popuation of each type.  It's entries sum to one.  Using the chain rule of calculus we can derive the following differential equation for $\theta$ from the above ode for $n$:
# $$
# \dot{\theta} = diag(\theta) \left( F\theta - \mathbf{1} \theta^T F \theta \right)
# $$
# where $\mathbf{1}$ is the column vector of ones (the derivation is a bit involved, try deriving it by yourself if interested, but it is not required). The two components of the vector $F \theta$ give the average fitness level of small crickets and large crickets, respectively, in an encounter with a cricket selected randomly from the population.   And $\theta^T F \theta$ is the weighted average of that vector, giving the average fitness over all crickets in the population.   Thus, $\theta[0]$ is increasing exactly when the fitness of small crickets is greater than the average fitness.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 4:</SPAN>**
#
# 1. Modify the above code to integrate the equation for the $\theta$ vector to obtain $\theta$ vs. time.
# To check your answer, compare it to what you get by first computing the trajectory of $n$ and then calculating $\theta$ from $n.$  (The code given above for deterministic evolution of n works for any number of types, not just two types. A problem below involves three types of individuals, so it'd be nice if you could implement your code for computing $\theta$ to work for any number of types.) __Be careful when you write your program, since matrix multiplication in Python can be tricky. Understand "$*$" multiplication and np.dot multiplication first. After each small step, debug, confirm, then proceed.__
# 2. Using the fact that $\theta[1]=1-\theta[0],$  a differential equation can be derived for the variable $\theta[0]$ alone.
# Plot the function $h$ on the interval $[0,1]$ such that $\dot{\theta}[0]=h(\theta[0]).$ Note that the horizontal axis of the graph is $\theta$, the vertical axis is $\dot{\theta}$. (You can just do this
# numerically.  It can also be done algebrically; in fact $h$ is a cubic polynomial, but it is a bit complicated to find the polynomial.)
# 3. What are the zeroes of $h$ (those are the equilibrium points of $\theta[0]$)?  Which of those are stable (in the sense that if $\theta[0]$ is slightly moved away from the equilibrium point, it returns to the equilibrium point)?

# %%
# Your code here

# part 1
print("Part 1")
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

# code for calculating theta
def f_theta(theta,t):
    return (theta * (np.dot(F,theta) - np.dot(theta, np.dot(F,theta))))

theta_init=[0.5,0.5]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

theta=odeint(f_theta,theta_init,time)

plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(time,theta[:,0],'orange')
plt.plot(time,theta[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,theta[800,0], r'$\theta[0]$',fontsize=14)
plt.text(1.1,theta[800,1], r'$\theta[1]$',fontsize=14)
plt.ylabel('value')
plt.title("$\\theta$ vs. time (ode prediction)")

# code for checking
def f_n(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[4,4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f_n,ninit,time)

theta_check = np.array([list(n[i]/np.sum(n, axis=1)[i]) for i in range(n.shape[0])]) # calculate theta from n

plt.subplot(122)
plt.plot(time,theta_check[:,0],'orange')
plt.plot(time,theta_check[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,theta_check[800,0], r'$\theta[0]$',fontsize=14)
plt.text(1.1,theta_check[800,1], r'$\theta[1]$',fontsize=14)
plt.ylabel('value')
plt.title("$\\theta$ vs. time (ode prediction, checking)")

plt.show()

# part 2
print("Part 2")

# numerically
def de_theta_0(theta):
    return (theta * (np.dot(F,theta) - np.dot(theta, np.dot(F,theta))))

theta_0=np.linspace(0.0,1.0, 1000)

dot_theta_0=[]

for i in range(len(theta_0)):
    dot_theta = de_theta_0(np.array([theta_0[i], 1-theta_0[i]]))
    dot_theta_0.append(dot_theta[0])
    
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(theta_0, dot_theta_0)
plt.axhline(y=0,c="orange")
plt.title('$h$ (numerically)')
plt.xlabel('$\\theta$')
plt.ylabel('$\dot{\\theta}$')

# algebrically
h = theta_0*(theta_0-1)*(2+theta_0)

plt.subplot(122)
plt.plot(theta_0,h)
plt.axhline(y=0,c="orange")
plt.title('$h$ (algebrically)')
plt.xlabel('$\\theta$')
plt.ylabel('$\dot{\\theta}$')

plt.show()
# Out:
# Part 1
# Part 2

# %% [markdown]
# __Answer:__ The zeros of $h$ are the equilibrium points of $\theta[0]$. In other words, when $h$ equals zero, $\theta[0]$ will remain the same. In our context, $\theta[0]$ will not change if it equals $0$ or $1$. The results make sense, because there is only one type of crickets in the population when $\theta[0]$ equals $0$ or $1$. Specifically, $h(0)=h(1)=0$. The zero with $\theta[0]$ equaling $0$ is stable while the zero with $\theta[0]$ equaling $1$ is not stable. Suppose $\theta[0]$ is $0$ initially. If $\theta[0]$ is slightly moved away from the equilibrium point, $h$ is negative so that $\theta[0]$ will be reduced back to $0$ again. However, $\theta[0]$ will not be increased back to $1$ again if it is slightly moved away from the equilibrium point, because $h$ is negative. Consequently, $\theta[0]$ will be reduced to $0$ once it is slightly moved away from $1$.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 4</SPAN>**

# %% [markdown]
# The overall behavior in evolutionary games depends heavily on the fitness matrix $F.$   Another choice of $F$ corresponds to the so-called doves and hawks evolution game, for which the fitness matrix is
# $$\begin{array}{c|cc}  & dove & hawk  \\ \hline
#     dove & 3 & 1  \\
#     hawk & 5 & 0
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  3 & 1 \\ 5 & 0  \end{array}\right).$$   Think of the doves and hawks as two types of birds that need to share resources, such as food.  (The hawks are so aggressive that they attack the doves).  A dove has higher fitness, 3, against another dove than against a hawk, 1.  A hawk has a high fitness against a dove (5) but zero fitness against another hawk, because the hawks fight over their resources.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 5:</SPAN>**
#
# 1. Repeat the deterministic (ode) approach above, but now for the doves and hawks evolution game.   You can use either the random or deterministic evolution equations for the numerical analysis.
# 2. Comment and verify your assertions about equilibrium behavior by finding a differential equation for $\theta[0]$ and exploring its equilbrium points and their stability.

# %%
# Your code here

# part 1
print('Part 1')
# Deterministic (ODE) replicator dynamics for doves and hawks game
from scipy.integrate import odeint

F=np.array([[3,1],[5,0]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[4,4]    # initial [number of doves, number of hawks]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'doves',fontsize=14)
plt.text(1.1,n[800,1], r'hawks',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of doves and hawks crickets vs. time (ode prediction)")

# code for calculating theta
def f_theta(theta,t):
    return (theta * (np.dot(F,theta) - np.dot(theta, np.dot(F,theta))))

theta_init=[0.5,0.5]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

theta=odeint(f_theta,theta_init,time)

plt.subplot(122)
plt.plot(time,theta[:,0],'orange')
plt.plot(time,theta[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,theta[800,0], r'$\theta[0]$',fontsize=14)
plt.text(1.1,theta[800,1], r'$\theta[1]$',fontsize=14)
plt.ylabel('value')
plt.title("$\\theta$ vs. time (ode prediction)")

plt.show()

# part 2
print("Part 2")

# numerically
def de_theta_0(theta):
    return (theta * (np.dot(F,theta) - np.dot(theta, np.dot(F,theta))))

theta_0=np.linspace(0.0,1.0, 1000)

dot_theta_0=[]

for i in range(len(theta_0)):
    dot_theta = de_theta_0(np.array([theta_0[i], 1-theta_0[i]]))
    dot_theta_0.append(dot_theta[0])
    
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(theta_0, dot_theta_0)
plt.axhline(y=0,c="orange")
plt.axvline(x=1/3,c="red")
plt.title('$h$ (numerically)')
plt.xlabel('$\\theta$')
plt.ylabel('$\dot{\\theta}$')

# algebrically
h = theta_0*(theta_0-1)*(3*theta_0-1)

plt.subplot(122)
plt.plot(theta_0,h)
plt.axhline(y=0,c="orange")
plt.axvline(x=1/3,c="red")
plt.title('$h$ (algebrically)')
plt.xlabel('$\\theta$')
plt.ylabel('$\dot{\\theta}$')

plt.show()
# Out:
# Part 1
# Part 2

# %% [markdown]
# __Answer__: After doing some algebra, I find the differential equation for $\theta[0]$ to be $h=\theta[0](\theta[0]-1)(3\theta[0]-1)$. Thus, the equilibrium points are $\theta[0]=0$, $\theta[0]=\frac{1}{3}$, and $\theta[0]=1$. When $\theta[0]$ is at any of these points, $\theta[0]$ remains the same. However, only $\theta[0]=\frac{1}{3}$ is stable. For $\theta[0]=0$, when $\theta[0]$ is slightly moved away from $0$, $h$ is positive so that $\theta[0]$ will be increased instead of being reduced back to $0$. For $\theta[0]=1$, when $\theta[0]$ is slightly moved away from $1$, $h$ is negative so that $\theta[0]$ will be reduced instead of being increased back to $1$. For $\theta[0]=\frac{1}{3}$, when $\theta[0]$ is slightly reduced from $\frac{1}{3}$, $h$ is positive so that $\theta[0]$ will be increased back to $\frac{1}{3}$; when $\theta[0]$ is slightly increased from $\frac{1}{3}$, $h$ is negative so that $\theta[0]$ will be reduced back to $\frac{1}{3}$.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 5</SPAN>**

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 6:</SPAN>**  Find a 3x3 fitness matrix $F$ and an initial condition for an evolutionary game with three types of individuals such that the solution $\theta$ has a limit cycle, not just converging to a limit point.  Does the limit cycle depend on the intial state for your fitness matrix?
#
# Hint 1: Adapt the code you wrote for Problem 4.
#
# Hint 2: Solve this problem by trial and error, i.e. trying different values of the entries in the fitness matrix. Think of the three types of individuals as three kinds of animals. What kind of relationship among these three animals would likely to cause an oscillating population for each animal?

# %%
# Your code here

# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[0,3,-3],[-3,0,3],[3,-3,0]])  # fitness matrix

# code for calculating theta
def f_theta(theta,t):
    return (theta * (np.dot(F,theta) - np.dot(theta, np.dot(F,theta))))

theta_init=[0.2,0.5,0.3]    # initial condition
time=np.linspace(0.0, 5.0, 4000)

theta=odeint(f_theta,theta_init,time)

plt.plot(time,theta[:,0],'orange')
plt.plot(time,theta[:,1],'blue')
plt.plot(time,theta[:,2],'red')
plt.xlabel('time')
plt.text(1.1,theta[800,0], r'$\theta[0]$',fontsize=14)
plt.text(1.1,theta[800,1], r'$\theta[1]$',fontsize=14)
plt.text(1.1,theta[800,2], r'$\theta[2]$',fontsize=14)
plt.ylabel('value')
plt.title("$\\theta$ vs. time (ode prediction)")

plt.show()

# %% [markdown]
# __Answer__: By observation, the limit cycle depends on the intial state.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 6</SPAN>**

# %% [markdown]
# For this week's lab, please answer all questions 1-6.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ## Academic Integrity Statement ##
#
# By submitting the lab with this statement, you declare you have written up the lab entirely by yourself, including both code and markdown cells. You also agree that you should not share your code with anyone else. Any violation of the academic integrity requirement may cause an academic integrity report to be filed that could go into your student record. See <a href="https://provost.illinois.edu/policies/policies/academic-integrity/students-quick-reference-guide-to-academic-integrity/">Students' Quick Reference Guide to Academic Integrity</a> for more information.
